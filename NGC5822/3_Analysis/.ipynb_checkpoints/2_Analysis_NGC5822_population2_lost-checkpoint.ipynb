# %%
import numpy as np
import pandas as pd
from astropy.io import ascii
import os
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
# %run -i /Users/marie/Documents/Research/dataproc/tools/cluster_tools.py

# %%
data = pd.read_csv('Catalogues/NGC5822_population2_lost.csv')
data
# Out:
#         RA_ICRS    DE_ICRS               Source     Plx   pmRA   pmDE  Solved  \
# 0    226.964782 -55.900104  5880575114680639488  1.1518 -7.280 -5.884      31
# 1    225.478188 -55.681735  5881380781843703040  1.2525 -7.781 -5.683      31
# 2    226.153399 -55.717696  5881387207115290368  1.1593 -7.530 -5.365      31
# 3    225.681373 -55.541256  5881404043388082560  1.2967 -7.110 -5.223      31
# 4    224.623523 -56.032550  5881458778464898944  1.1517 -7.719 -5.169      31
# ..          ...        ...                  ...     ...    ...    ...     ...
# 108  224.746220 -53.610175  5899796708259124352  1.2995 -7.758 -5.572      31
# 109  225.055878 -53.182328  5899835775283387136  1.1455 -7.159 -5.756      31
# 110  224.813303 -53.151743  5899845396010785920  1.2183 -7.914 -5.132      31
# 111  225.981860 -52.964491  5899886765128211200  1.2670 -7.827 -5.348      31
# 112  223.973185 -53.107410  5900018947033104128  1.1424 -7.406 -5.137      31
#
#      nueff  pscol   RUWE       Gmag      BPmag      RPmag     BP-RP     RV  \
# 0    1.395    NaN  1.017  16.938236  17.682375  16.052890  1.629484    NaN
# 1    1.584    NaN  0.916  12.982288  13.249472  12.548177  0.701295 -17.67
# 2    1.445    NaN  1.005  16.106497  16.707300  15.368125  1.339175    NaN
# 3    1.548    NaN  0.920  13.714863  14.057667  13.201783  0.855884  26.90
# 4    1.599    NaN  0.909  12.289694  12.524664  11.897099  0.627565 -27.72
# ..     ...    ...    ...        ...        ...        ...       ...    ...
# 108  1.526    NaN  0.930  14.170815  14.560180  13.609451  0.950728   4.13
# 109  1.556    NaN  0.984  13.477468  13.800722  12.986613  0.814109 -56.52
# 110  1.533    NaN  0.947  14.380452  14.750266  13.825043  0.925223   0.18
# 111  1.574    NaN  0.978  13.357611  13.645534  12.906324  0.739209 -32.35
# 112  1.538    NaN  1.053  14.113292  14.472841  13.574273  0.898568 -25.16
#
#           ELAT     RAJ2000    DEJ2000  Plx_corr
# 0   -36.635825  226.964840 -55.900078  1.181979
# 1   -36.717506  225.478249 -55.681710  1.284755
# 2   -36.619735  226.153458 -55.717672  1.191565
# 3   -36.545939  225.681429 -55.541233  1.337292
# 4   -37.214618  224.623584 -56.032527  1.180923
# ..         ...         ...        ...       ...
# 108 -34.920681  224.746279 -53.610151  1.340445
# 109 -34.455467  225.055931 -53.182302  1.186468
# 110 -34.476388  224.813362 -53.151720  1.259558
# 111 -34.062790  225.981918 -52.964467  1.308210
# 112 -34.608718  223.973240 -53.107387  1.183518
#
# [113 rows x 19 columns]

# %%
fig,ax = plt.subplots(1,4, figsize=(16,4),tight_layout=True)
pop = data
ax[0].scatter(pop.RAJ2000, pop.DEJ2000, color='k', s=(19.5-pop.Gmag)*6, alpha=0.3)
ax[0].set_xlabel("RA (deg)",fontsize=16)
ax[0].set_ylabel("DEC (deg)",fontsize=16)
ax[1].scatter(pop.pmRA, pop.pmDE, color='k', s=(19.5-pop.Gmag)*6, alpha=0.3)
ax[1].set_xlabel("pmRA (mas/yr)",fontsize=16)
ax[1].set_ylabel("pmDE (mas/yr)",fontsize=16)
ax[2].scatter(pop.Plx_corr, pop.Gmag, color='k', s=(19.5-pop.Gmag)*6, alpha=0.3)
ax[2].set_ylim(19,8)
ax[2].set_xlabel("Plx (mas)",fontsize=16)
ax[2].set_ylabel("Gmag (mag)",fontsize=16)
ax[3].scatter(pop["BP-RP"], pop.Gmag, color='k', s=(19.5-pop.Gmag)*6, alpha=0.3)
ax[3].set_ylim(19,8)
ax[3].set_xlabel("BP-RP (mag)",fontsize=16)
ax[3].set_ylabel("Gmag (mag)",fontsize=16)

ax[0].tick_params(labelsize=14)
ax[1].tick_params(labelsize=14)
ax[2].tick_params(labelsize=14)
ax[3].tick_params(labelsize=14)
