# %%
import numpy as np
import pandas as pd
from astropy.io import ascii
from astropy.coordinates import SkyCoord
from astropy import units as u
import os
import matplotlib.pyplot as plt
import mpl_scatter_density

# %% [markdown]
# # Comparing catalogue (vG+2023)

# %%
df_vg =  pd.read_csv('Catalogues/NGC5822_vG2023+GaiaDR3.csv')
df_vg
# Out:
#        Cluster              GaiaDR3     RA_ICRS    DE_ICRS     Plx   pmRA  \
# 0     NGC_5822  5881692149823656320  224.731239 -54.566271  1.1099 -7.637
# 1     NGC_5822  5881693146252823040  225.029198 -54.642280  1.2323 -7.615
# 2     NGC_5822  5881693008813852032  225.093020 -54.639486  1.1770 -7.513
# 3     NGC_5822  5881621849790430720  225.256861 -54.944673  1.2361 -7.625
# 4     NGC_5822  5881581129144018944  224.939856 -55.470265  1.1691 -7.361
# ...        ...                  ...         ...        ...     ...    ...
# 3806  NGC_5822  5887682941959525632  225.462268 -54.661084  1.2073 -7.094
# 3807  NGC_5822  5887513479716081408  228.244040 -54.481390  1.2680 -7.562
# 3808  NGC_5822  5887644802678111616  225.789618 -54.490146  1.2263 -7.360
# 3809  NGC_5822  5887409644592719744  226.436096 -55.149314  0.8496 -7.272
# 3810  NGC_5822  5880575114680639488  226.964782 -55.900104  1.1518 -7.280
#
#        pmDE       Gmag      BPmag      RPmag  ...  E(BP-RP) b_E(BP-RP)_x  \
# 0    -5.249  14.223904  14.590719  13.684692  ...       NaN          NaN
# 1    -5.588  13.173482  13.473589  12.706505  ...    0.2934       0.2906
# 2    -5.336  17.276005  18.127857  16.374056  ...    0.3402       0.3291
# 3    -4.914  10.945331  11.127864  10.621691  ...       NaN          NaN
# 4    -6.179  17.633880  18.448076  16.705523  ...    0.2559       0.2192
# ...     ...        ...        ...        ...  ...       ...          ...
# 3806 -4.968  19.999956  20.675339  18.942724  ...       NaN          NaN
# 3807 -4.841  19.671330  20.907232  18.590193  ...       NaN          NaN
# 3808 -5.264  14.942392  15.364985  14.344611  ...    0.0127       0.0036
# 3809 -5.059  19.407978  20.748910  18.374445  ...       NaN          NaN
# 3810 -5.884  16.938236  17.682375  16.052890  ...    0.5231       0.5039
#
#       B_E(BP-RP)_xa      Lib     RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  \
# 0               NaN      NaN  224.731298 -54.566248   0.341326   0.333229
# 1            0.2962        A  225.029257 -54.642255   0.219421   0.231904
# 2            0.3522  PHOENIX  225.093078 -54.639462   1.215334   1.216434
# 3               NaN      NaN  225.256920 -54.944652   0.230675   0.238101
# 4            0.2934  PHOENIX  224.939914 -55.470237   1.450671   1.829419
# ...             ...      ...         ...        ...        ...        ...
# 3806            NaN      NaN  225.462322 -54.661062   7.778286   7.457061
# 3807            NaN      NaN  228.244098 -54.481369   6.284833   7.602907
# 3808         0.0230    MARCS  225.789675 -54.490122   0.383133   0.494652
# 3809            NaN      NaN  226.436153 -55.149292   6.470691   9.169844
# 3810         0.5512  PHOENIX  226.964840 -55.900078   1.178003   1.315606
#
#       RADEcorJ2000  angDist
# 0          -0.4286      0.0
# 1          -0.2935      0.0
# 2          -0.1546      0.0
# 3          -0.2818      0.0
# 4          -0.3321      0.0
# ...            ...      ...
# 3806        0.1268      0.0
# 3807       -0.0883      0.0
# 3808       -0.2939      0.0
# 3809       -0.3229      0.0
# 3810       -0.4344      0.0
#
# [3811 rows x 149 columns]

# %%
jj, = np.where(df_vg.Pmemb >= 0.7)
dfvg = df_vg.iloc[jj]

# %%
dfvg
# Out:
#        Cluster              GaiaDR3     RA_ICRS    DE_ICRS     Plx   pmRA  \
# 0     NGC_5822  5881692149823656320  224.731239 -54.566271  1.1099 -7.637
# 1     NGC_5822  5881693146252823040  225.029198 -54.642280  1.2323 -7.615
# 2     NGC_5822  5881693008813852032  225.093020 -54.639486  1.1770 -7.513
# 3     NGC_5822  5881621849790430720  225.256861 -54.944673  1.2361 -7.625
# 9     NGC_5822  5881663734314222848  224.529052 -54.907023  1.2427 -8.045
# ...        ...                  ...         ...        ...     ...    ...
# 3788  NGC_5822  5887644076778836992  225.766634 -54.552180  1.2115 -7.631
# 3790  NGC_5822  5887682907633247232  225.485704 -54.661399  1.2133 -7.699
# 3792  NGC_5822  5887644802678106752  225.802585 -54.496725  1.0860 -7.484
# 3808  NGC_5822  5887644802678111616  225.789618 -54.490146  1.2263 -7.360
# 3810  NGC_5822  5880575114680639488  226.964782 -55.900104  1.1518 -7.280
#
#        pmDE       Gmag      BPmag      RPmag  ...  E(BP-RP) b_E(BP-RP)_x  \
# 0    -5.249  14.223904  14.590719  13.684692  ...       NaN          NaN
# 1    -5.588  13.173482  13.473589  12.706505  ...    0.2934       0.2906
# 2    -5.336  17.276005  18.127857  16.374056  ...    0.3402       0.3291
# 3    -4.914  10.945331  11.127864  10.621691  ...       NaN          NaN
# 9    -5.691  15.783429  16.332071  15.084052  ...    0.2014       0.1932
# ...     ...        ...        ...        ...  ...       ...          ...
# 3788 -5.502  17.686186  18.633373  16.712296  ...    0.3172       0.2954
# 3790 -5.579  13.759797  14.118023  13.219545  ...       NaN          NaN
# 3792 -5.220  16.826729  17.568169  15.986682  ...    0.1613       0.1489
# 3808 -5.264  14.942392  15.364985  14.344611  ...    0.0127       0.0036
# 3810 -5.884  16.938236  17.682375  16.052890  ...    0.5231       0.5039
#
#       B_E(BP-RP)_xa      Lib     RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  \
# 0               NaN      NaN  224.731298 -54.566248   0.341326   0.333229
# 1            0.2962        A  225.029257 -54.642255   0.219421   0.231904
# 2            0.3522  PHOENIX  225.093078 -54.639462   1.215334   1.216434
# 3               NaN      NaN  225.256920 -54.944652   0.230675   0.238101
# 9            0.2110    MARCS  224.529115 -54.906998   0.564024   0.674880
# ...             ...      ...         ...        ...        ...        ...
# 3788         0.3487    MARCS  225.766693 -54.552156   1.551876   1.830193
# 3790            NaN      NaN  225.485763 -54.661374   0.237196   0.260675
# 3792         0.1749  PHOENIX  225.802642 -54.496702   0.989988   1.443266
# 3808         0.0230    MARCS  225.789675 -54.490122   0.383133   0.494652
# 3810         0.5512  PHOENIX  226.964840 -55.900078   1.178003   1.315606
#
#       RADEcorJ2000  angDist
# 0          -0.4286      0.0
# 1          -0.2935      0.0
# 2          -0.1546      0.0
# 3          -0.2818      0.0
# 9          -0.3561      0.0
# ...            ...      ...
# 3788       -0.2104      0.0
# 3790       -0.1946      0.0
# 3792       -0.3447      0.0
# 3808       -0.2939      0.0
# 3810       -0.4344      0.0
#
# [850 rows x 149 columns]

# %% [markdown]
# # 4 Populations

# %%
p1 = pd.read_csv('Catalogues/pop1_NGC5822_GMM3.csv')
p2 = pd.read_csv('Catalogues/pop2_NGC5822_GMM3.csv')
p3 = pd.read_csv('Catalogues/pop3_NGC5822_GMM3.csv')
p4 = pd.read_csv('Catalogues/pop4_NGC5822_GMM3.csv')

# %% [markdown]
# ## Computing Completeness and Purity

# %% [markdown]
# ### Population 1

# %%
ra1 = p1.RAJ2000
dec1 = p1.DEJ2000

ra2 = dfvg.RAJ2000
dec2 = dfvg.DEJ2000

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p1.iloc[matched_idx_catalog1]
# Out:
# Empty DataFrame
# Columns: [RAJ2000, DEJ2000, pmRA, pmDE, Gmag, BP-RP, Plx, cluster]
# Index: []

# %%
dfvg.iloc[matched_idx_catalog2]
# Out:
# Empty DataFrame
# Columns: [Cluster, GaiaDR3, RA_ICRS, DE_ICRS, Plx, pmRA, pmDE, Gmag, BPmag, RPmag, Pmemb, DR3Name, RAdeg, DEdeg, errHalfMaj, errHalfMin, errPosAng, SolID, Source, RandomI, e_RAdeg, e_DEdeg, Plx_x, e_Plx, RPlx, PM, pmRA_x, e_pmRA, pmDE_x, e_pmDE, RADEcor, RAPlxcor, RApmRAcor, RApmDEcor, DEPlxcor, DEpmRAcor, DEpmDEcor, PlxpmRAcor, PlxpmDEcor, pmRApmDEcor, NAL, NAC, NgAL, NbAL, gofAL, chi2AL, epsi, sepsi, Solved, APF, nueff, pscol, e_pscol, RApscolCorr, DEpscolCorr, PlxpscolCorr, pmRApscolCorr, pmDEpscolCorr, MatchObsA, Nper, amax, MatchObs, IPDgofha, IPDgofhp, IPDfmp, IPDfow, RUWE, Dup, o_Gmag, FG, e_FG, RFG, Gmag_x, e_Gmag, o_BPmag, FBP, e_FBP, RFBP, BPmag_x, e_BPmag, o_RPmag, FRP, e_FRP, RFRP, RPmag_x, e_RPmag, E(BP/RP), NBPcont, NBPblend, NRPcont, NRPblend, Mode, BP-RP, BP-G, G-RP, RV, e_RV, n_RV, o_RV, o_RVd, ...]
# Index: []
#
# [0 rows x 149 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(p1.RAJ2000, p1.DEJ2000, s=1, c='grey')
ax.scatter(dfvg.RAJ2000, dfvg.DEJ2000, s=1, c='b')
ax.scatter(p1.iloc[matched_idx_catalog1].RAJ2000, p1.iloc[matched_idx_catalog1].DEJ2000, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
# ax.set_ylim(-11.5,-14.2)
# ax.set_xlim(121.2,124.5)
# Out:
# Text(0, 0.5, 'DEC (deg)')

# %%
dfvg_t = len(dfvg)
p1_t = len(p1.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p1_c = p1_t /dfvg_t
p1_c*100
# Out:
# 0.0

# %% [markdown]
# Pureness

# %%
p1_p = p1_t/len(p1)
p1_p*100
# Out:
# 0.0

# %% [markdown]
# ### Population 2

# %%
ra1 = p2.RAJ2000
dec1 = p2.DEJ2000

ra2 = dfvg.RAJ2000
dec2 = dfvg.DEJ2000

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p2
# Out:
#          RAJ2000    DEJ2000   pmRA   pmDE       Gmag     BP-RP     Plx  \
# 0     227.336537 -56.170745 -6.473 -6.232  13.967035  0.905355  1.2236
# 1     227.149135 -56.119524 -8.831 -5.332  20.694818  1.633688  1.1480
# 2     226.859952 -56.223042 -9.122 -3.641  13.939487  0.852195  1.2154
# 3     226.902096 -56.152605 -5.875 -4.625  20.813010  1.399567  1.3204
# 4     227.136449 -56.116648 -8.346 -7.390  12.018602  0.760868  1.1876
# ...          ...        ...    ...    ...        ...       ...     ...
# 4226  226.521177 -52.405487 -8.848 -6.819  19.696411  1.809648  1.1750
# 4227  226.429106 -52.427262 -5.960 -6.230  20.341524  1.651640  1.2397
# 4228  226.362966 -52.402928 -8.500 -5.627  20.185804  1.750360  1.1699
# 4229  226.571315 -52.390856 -5.840 -6.054  19.183874  2.169256  1.1524
# 4230  226.541488 -52.392520 -5.731 -7.222  19.153725  1.663042  1.2887
#
#       cluster
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# 1311         0.2233        A  225.478249 -55.681710   0.239109   0.247591
# 1284         0.1711    MARCS  226.153458 -55.717672   0.644677   0.613090
# 2064         0.1485  PHOENIX  225.681429 -55.541233   0.235066   0.276642
# 1537         0.3717        A  224.623584 -56.032527   0.186739   0.208676
# ...             ...      ...         ...        ...        ...        ...
# 984          0.1285    MARCS  225.055931 -53.182302   0.253235   0.347012
# 989          0.1493    MARCS  224.813362 -53.151720   0.311401   0.436078
# 3759            NaN      NaN  225.981918 -52.964467   0.202012   0.223100
# 3738         0.3447    MARCS  225.632394 -52.932365   1.194547   1.311843
# 3526         0.2924  PHOENIX  223.973240 -53.107387   0.234570   0.281816
#
#       RADEcorJ2000  angDist
# 3810       -0.4344      0.0
# 1311       -0.2298      0.0
# 1284       -0.1829      0.0
# 2064       -0.2901      0.0
# 1537       -0.2841      0.0
# ...            ...      ...
# 984        -0.5460      0.0
# 989        -0.4481      0.0
# 3759       -0.3587      0.0
# 3738       -0.3811      0.0
# 3526       -0.3809      0.0
#
# [706 rows x 149 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(p2.RAJ2000, p2.DEJ2000, s=1, c='grey')
ax.scatter(dfvg.RAJ2000, dfvg.DEJ2000, s=1, c='b')
ax.scatter(p2.iloc[matched_idx_catalog1].RAJ2000, p2.iloc[matched_idx_catalog1].DEJ2000, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
# ax.set_ylim(-11.5,-14.2)
# ax.set_xlim(121.2,124.5)
# Out:
# Text(0, 0.5, 'DEC (deg)')

# %%
dfvg_t = len(dfvg)
p2_t = len(p2.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p2_c = p2_t /dfvg_t
p2_c*100
# Out:
# 83.05882352941177

# %% [markdown]
# Pureness

# %%
p2_p = p2_t/len(p2)
p2_p*100
# Out:
# 16.68636256204207

# %% [markdown]
# ### Population 3

# %%
ra1 = p3.RAJ2000
dec1 = p3.DEJ2000

ra2 = dfvg.RAJ2000
dec2 = dfvg.DEJ2000

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p3.iloc[matched_idx_catalog1]
# Out:
#          RAJ2000    DEJ2000   pmRA   pmDE       Gmag     BP-RP     Plx  \
# 862   223.760734 -55.344302 -7.487 -5.748  16.466734  1.414545  1.1152
# 960   225.270886 -55.485639 -7.798 -5.539  17.944447  1.924454  1.0986
# 1056  224.961534 -55.213613 -7.512 -5.034  17.349474  1.875168  1.2689
# 3165 -5.585  17.612474  18.508526  16.662775  ...    0.0689       0.0575
# 3474 -5.742  17.842188  18.702570  16.706960  ...    0.2929       0.2748
# 3375 -5.533  18.635350  19.836365  17.492886  ...    0.3065       0.2756
# 3221 -5.711  18.841824  20.181654  17.812992  ...    0.1322       0.0997
# 3235 -5.570  18.433466  19.786041  17.296278  ...    0.2142       0.1984
# 3292 -5.646  18.287031  19.421064  17.287500  ...    0.4550       0.4308
# 3271 -5.701  18.369164  19.492678  17.354685  ...    0.2502       0.2352
# 3166 -5.634  18.699467  19.948242  17.663244  ...    0.2123       0.1811
# 2035 -5.214  18.472645  19.825780  17.392952  ...    0.3002       0.2784
# 2797 -5.061  18.436098  19.435095  17.353367  ...    0.2143       0.1649
#
#       B_E(BP-RP)_xa      Lib     RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  \
# 1510         0.1773  PHOENIX  223.760734 -55.344302   0.835923   0.904408
# 438          0.3836  PHOENIX  225.270886 -55.485639   1.771798   1.910727
# 1017         0.3428  PHOENIX  224.961534 -55.213613   1.452612   1.774935
# 76           0.4884    MARCS  225.516540 -54.972653   1.674362   1.671096
# 1236         0.4347    MARCS  225.550404 -54.816960   1.440665   1.377784
# 3165         0.0763  PHOENIX  226.323318 -54.840367   1.759962   2.359372
# 3474         0.3110    MARCS  227.313672 -54.749912   1.913480   1.675265
# 3375         0.3431  PHOENIX  226.640728 -54.797785   2.721602   3.175575
# 3221         0.1597  PHOENIX  226.609180 -54.636259   3.031673   3.255709
# 3235         0.2290    MARCS  226.870311 -54.662378   2.385003   2.324627
# 3292         0.4745  PHOENIX  226.909801 -54.574571   2.209102   2.136701
# 3271         0.2633  PHOENIX  226.994456 -54.557415   2.316157   2.265765
# 3166         0.2436    MARCS  226.651994 -54.533703   2.899596   2.889067
# 2035         0.3186  PHOENIX  227.714712 -54.810646   2.321318   2.500834
# 2797         0.2571  PHOENIX  225.804123 -54.631363   2.267085   2.496189
#
#       RADEcorJ2000  angDist
# 1510       -0.2372      0.0
# 438        -0.1220      0.0
# 1017       -0.2587      0.0
# 76         -0.1196      0.0
# 1236       -0.1632      0.0
# 3165       -0.5437      0.0
# 3474       -0.1185      0.0
# 3375       -0.2555      0.0
# 3221       -0.0841      0.0
# 3235       -0.1661      0.0
# 3292       -0.2548      0.0
# 3271       -0.2486      0.0
# 3166       -0.0824      0.0
# 2035       -0.2128      0.0
# 2797       -0.2107      0.0
#
# [15 rows x 149 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(p3.RAJ2000, p3.DEJ2000, s=1, c='grey')
ax.scatter(dfvg.RAJ2000, dfvg.DEJ2000, s=1, c='b')
ax.scatter(p3.iloc[matched_idx_catalog1].RAJ2000, p3.iloc[matched_idx_catalog1].DEJ2000, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
# ax.set_ylim(-11.5,-14.2)
# ax.set_xlim(121.2,124.5)
# Out:
# Text(0, 0.5, 'DEC (deg)')

# %%
dfvg_t = len(dfvg)
p3_t = len(p3.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p3_c = p3_t /dfvg_t
p3_c*100
# Out:
# 1.7647058823529411

# %% [markdown]
# Pureness

# %%
p3_p = p3_t/len(p3)
p3_p*100
# Out:
# 0.6318449873631002

# %% [markdown]
# ### Population 4

# %%
ra1 = p4.RAJ2000
dec1 = p4.DEJ2000

ra2 = dfvg.RAJ2000
dec2 = dfvg.DEJ2000

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p4.iloc[matched_idx_catalog1]
# Out:
#          RAJ2000    DEJ2000   pmRA   pmDE       Gmag     BP-RP     Plx  \
# 668   227.687892 -54.703502 -7.065 -5.471  18.362644  2.212345  1.1385
# 1005  228.235274 -53.970230 -6.924 -5.576  16.529398  1.435196  1.2016
# 1078  227.527402 -54.227469 -7.139 -5.195  17.787687  1.923801  1.2754
# 1086  227.086162 -54.363821 -7.290 -5.671  18.055210  1.985251  1.0945
# 1139  227.309501 -54.126367 -7.004 -5.325  17.195107  1.799168  1.1054
# 1150  227.365007 -54.007598 -7.090 -5.616  18.158234  2.103125  1.1848
# 1228  227.824081 -54.055409 -7.391 -5.688  17.366590  1.799517  1.3043
# 1470  227.036737 -54.001933 -7.513 -5.528  17.735159  1.902540  1.2743
# 1599  227.594923 -53.577140 -7.031 -5.235  16.234318  1.327342  1.1727
# 1643  227.140835 -53.679080 -7.439 -5.056  16.554722  1.476688  1.1802
# 1648  227.045925 -53.607445 -7.160 -5.557  17.452290  1.775469  1.1173
# 1663  226.987171 -53.621358 -7.340 -5.261  17.598284  1.915684  1.1047
# 1699  227.316917 -53.352547 -7.355 -5.490  16.765852  1.536398  1.1910
# 1841  228.696484 -54.217827 -7.077 -5.860  16.710571  1.717073  1.2451
# 2504  228.002459 -53.692141 -6.980 -5.525  16.540514  1.438294  1.2053
# 2591  228.207922 -53.376471 -7.338 -5.577  10.012971  1.258349  1.2398
# 2869  227.709293 -53.396883 -7.124 -5.928  16.189749  1.365866  1.2803
#
#       cluster
# 668         3
# 1005        3
# 1078        3
# 1086        3
# 1139        3
# 1150        3
# 1228        3
# 1470        3
# 1599        3
# 1643        3
# 1648        3
# 1663        3
# 1699        3
# 1841        3
# 2504        3
# 2591        3
# 2869        3

# %%
dfvg.iloc[matched_idx_catalog2]
# Out:
#        Cluster              GaiaDR3     RA_ICRS    DE_ICRS     Plx   pmRA  \
# 1434  NGC_5822  5887492687767321216  227.687838 -54.703526  1.1385 -7.065
# 2358         0.2010  PHOENIX  227.086162 -54.363821   1.851337   1.847650
# 1887         0.3377  PHOENIX  227.309501 -54.126367   1.436220   1.696039
# 2105         0.2599  PHOENIX  227.365007 -54.007598   2.375200   2.306083
# 1375         0.3261    MARCS  227.824081 -54.055409   1.449495   1.580661
# 59           0.1761  PHOENIX  227.036737 -54.001933   1.539734   1.491368
# 745          0.1800    MARCS  227.594923 -53.577140   0.805053   0.900257
# 2550         0.2497    MARCS  227.140835 -53.679080   0.947166   1.439487
# 2781         0.2841  PHOENIX  227.045925 -53.607445   1.258274   1.416524
# 3038         0.4081    MARCS  226.987171 -53.621358   1.399471   1.477153
# 289          0.2030    MARCS  227.316917 -53.352547   0.976310   1.208988
# 702          0.2449  PHOENIX  228.696484 -54.217827   0.855624   0.848757
# 1265         0.1839  PHOENIX  228.002459 -53.692141   0.872242   0.816042
# 1209         0.0537  PHOENIX  228.207922 -53.376471   0.210080   0.231722
# 2405         0.2013    MARCS  227.709293 -53.396883   0.655217   0.674410
#
#       RADEcorJ2000  angDist
# 1434       -0.1147      0.0
# 2918       -0.2793      0.0
# 2739       -0.1523      0.0
# 2358       -0.1197      0.0
# 1887       -0.3663      0.0
# 2105       -0.1364      0.0
# 1375       -0.3182      0.0
# 59         -0.0932      0.0
# 745        -0.4340      0.0
# 2550       -0.4341      0.0
# 2781       -0.1747      0.0
# 3038       -0.2042      0.0
# 289        -0.4273      0.0
# 702        -0.1816      0.0
# 1265       -0.2466      0.0
# 1209       -0.1953      0.0
# 2405       -0.2861      0.0
#
# [17 rows x 149 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(p4.RAJ2000, p4.DEJ2000, s=1, c='grey')
ax.scatter(dfvg.RA_ICRS, dfvg.DE_ICRS, s=1, c='b')
ax.scatter(p4.iloc[matched_idx_catalog1].RAJ2000, p4.iloc[matched_idx_catalog1].DEJ2000, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
# ax.set_ylim(-11.5,-14.2)
# ax.set_xlim(121.2,124.5)
# Out:
# Text(0, 0.5, 'DEC (deg)')

# %%
dfvg_t = len(dfvg)
p4_t = len(p4.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p4_c = p4_t /dfvg_t
p4_c*100
# Out:
# 2.0

# %% [markdown]
# Pureness

# %%
p4_p = p4_t/len(p4)
p4_p*100
# Out:
# 0.49246813441483195

# %% [markdown]
# ## Analyzing

# %%
import seaborn as sns

# Dados simulados: completude e pureza por cluster
clusters = [1, 2, 3, 4]
completeness = [p1_c, p2_c, p3_c, p4_c]  # Exemplo de completude
purity = [p1_p, p2_p, p3_p, p4_p]  # Exemplo de pureza

# Bar plot
x = range(len(clusters))
plt.bar(x, completeness, width=0.4, label="Completeness", alpha=0.8, align='center')
plt.bar(x, purity, width=0.4, label="Purity", alpha=0.8, align='edge')

plt.xticks(x, [f"Cluster {c}" for c in clusters])
plt.ylabel("Value")
plt.title("Completeness and Purity by Cluster")
plt.legend()
plt.show()
