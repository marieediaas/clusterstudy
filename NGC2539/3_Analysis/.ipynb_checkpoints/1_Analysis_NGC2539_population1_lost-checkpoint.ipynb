# 9   0.0152  2.246 -2.244   0.017  ...  0.972  12.827418  13.011787  12.516235
# 10  0.0449  2.208 -2.161   0.044  ...  1.025  16.237015  16.807354  15.525974
# 11  0.0134  2.296 -2.090   0.015  ...  0.965  13.113413  13.286472  12.819208
# 12  0.0167  1.999 -1.958   0.020  ...  0.950  11.901287  12.032527  11.661114
# 13  0.0141  2.355 -2.142   0.015  ...  1.091  13.506442  13.721246  13.152643
# 14  0.0136  2.483 -2.483   0.014  ...  0.887  12.101497  12.194572  11.927140
# 15  0.0664  2.501 -2.492   0.068  ...  1.049  16.888363  17.509094  16.139294
# 16  0.0630  2.433 -2.383   0.058  ...  0.974  16.809248  17.456442  15.993611
# 17  0.0658  2.500 -2.442   0.064  ...  1.057  16.861015  17.404684  16.179090
# 18  0.0353  2.304 -2.222   0.033  ...  1.025  15.751667  16.133024  15.208096
# 19  0.0276  2.347 -2.289   0.027  ...  1.037  15.343348  15.686052  14.838098
# 20  0.0552  2.498 -2.425   0.056  ...  1.004  16.628176  17.135248  15.970446
#
#        BP-RP     RV       ELAT     RAJ2000    DEJ2000  Plx_corr
# 0   0.918681    NaN -32.673928  122.818787 -13.543956  0.815280
# 1   1.272512  24.43 -32.325244  123.105817 -13.257325  0.695821
# 2   1.362175    NaN -32.583117  122.704728 -13.420700  0.717649
# 3   0.774223  48.77 -32.618932  122.630293 -13.438656  0.837960
# 4   1.484718    NaN -32.424699  122.871253 -13.299649  0.869006
# 5   0.636224  36.80 -32.081567  123.005507 -12.979301  0.800698
# 6   1.551884    NaN -32.124605  122.742831 -12.956337  0.748141
# 7   0.696197  30.85 -31.900350  123.083194 -12.811882  0.812157
# 8   0.856234    NaN -32.192474  122.601534 -12.990396  0.868827
# 9   0.495552  34.37 -32.104811  122.595697 -12.898294  0.804329
# 10  1.281380    NaN -32.290031  122.203675 -12.990246  0.736618
# 11  0.467264    NaN -31.943353  122.769261 -12.775705  0.810934
# 12  0.371413  20.05 -32.032940  122.558551 -12.814549  0.779125
# 13  0.568603  38.74 -31.943911  122.624929 -12.739434  0.781610
# 14  0.267431  25.05 -31.943996  122.587126 -12.729901  0.821930
# 15  1.369801    NaN -31.733289  122.869670 -12.584236  0.844464
# 16  1.462830    NaN -32.241933  121.975298 -12.883124  0.833813
# 17  1.225594    NaN -32.081083  121.936632 -12.707376  0.793513
# 18  0.924929    NaN -31.980576  121.995886 -12.618442  0.837820
# 19  0.847955    NaN -31.785136  121.986930 -12.414451  0.771788
# 20  1.164803    NaN -31.515052  122.423167 -12.245165  0.722914
#
# [21 rows x 25 columns]

# %%
fig,ax = plt.subplots(1,4, figsize=(16,4),tight_layout=True)
pop = data
ax[0].scatter(pop.RAJ2000, pop.DEJ2000, color='k', s=(19.5-pop.Gmag)*6, alpha=0.3)
ax[0].set_xlabel("RA (deg)",fontsize=16)
ax[0].set_ylabel("DEC (deg)",fontsize=16)
ax[1].scatter(pop.pmRA, pop.pmDE, color='k', s=(19.5-pop.Gmag)*6, alpha=0.3)
ax[1].set_xlabel("pmRA (mas/yr)",fontsize=16)
ax[1].set_ylabel("pmDE (mas/yr)",fontsize=16)
ax[2].scatter(pop.Plx_corr, pop.Gmag, color='k', s=(19.5-pop.Gmag)*6, alpha=0.3)
ax[2].set_ylim(19,8)
ax[2].set_xlabel("Plx (mas)",fontsize=16)
ax[2].set_ylabel("Gmag (mag)",fontsize=16)
ax[3].scatter(pop["BP-RP"], pop.Gmag, color='k', s=(19.5-pop.Gmag)*6, alpha=0.3)
ax[3].set_ylim(19,8)
ax[3].set_xlabel("BP-RP (mag)",fontsize=16)
ax[3].set_ylabel("Gmag (mag)",fontsize=16)

ax[0].tick_params(labelsize=14)
ax[1].tick_params(labelsize=14)
ax[2].tick_params(labelsize=14)
ax[3].tick_params(labelsize=14)

# %%
data2 = data[((data["BP-RP"] > 1.0)&(data.Gmag > 15))]
data3 = data[((data["BP-RP"] < 1.0)&(data.Gmag > 10))]

# %%
fig,ax = plt.subplots(1,4, figsize=(16,4),tight_layout=True)
pop = data2
ax[0].scatter(pop.RAJ2000, pop.DEJ2000, color='k', s=(19.5-pop.Gmag)*6, alpha=0.3)
ax[0].scatter(data3.RAJ2000, data3.DEJ2000, color='k', s=(19.5-data3.Gmag)*6, alpha=0.3)
ax[0].set_xlabel("RA (deg)",fontsize=16)
ax[0].set_ylabel("DEC (deg)",fontsize=16)
ax[1].scatter(pop.pmRA, pop.pmDE, color='k', s=(19.5-pop.Gmag)*6, alpha=0.3)
ax[1].scatter(data3.pmRA, data3.pmDE, color='k', s=(19.5-data3.Gmag)*6, alpha=0.3)
ax[1].set_xlabel("pmRA (mas/yr)",fontsize=16)
ax[1].set_ylabel("pmDE (mas/yr)",fontsize=16)
ax[2].scatter(pop.Plx_corr, pop.Gmag, color='k', s=(19.5-pop.Gmag)*6, alpha=0.3)
ax[2].scatter(data3.Plx_corr, data3.Gmag, color='k', s=(19.5-data3.Gmag)*6, alpha=0.3)
ax[2].set_ylim(19,8)
ax[2].set_xlabel("Plx (mas)",fontsize=16)
ax[2].set_ylabel("Gmag (mag)",fontsize=16)
ax[3].scatter(pop["BP-RP"], pop.Gmag, color='k', s=(19.5-pop.Gmag)*6, alpha=0.3)
ax[3].scatter(data3["BP-RP"], data3.Gmag, color='k', s=(19.5-data3.Gmag)*6, alpha=0.3)
ax[3].set_ylim(19,8)
ax[3].set_xlabel("BP-RP (mag)",fontsize=16)
ax[3].set_ylabel("Gmag (mag)",fontsize=16)

ax[0].tick_params(labelsize=14)
ax[1].tick_params(labelsize=14)
ax[2].tick_params(labelsize=14)
ax[3].tick_params(labelsize=14)
