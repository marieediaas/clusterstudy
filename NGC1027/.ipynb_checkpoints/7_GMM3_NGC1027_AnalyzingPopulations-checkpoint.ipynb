# %%
import numpy as np
import pandas as pd
from astropy.io import ascii
from astropy.coordinates import SkyCoord
from astropy import units as u
import os
import matplotlib.pyplot as plt
import mpl_scatter_density

# %% [markdown]
# # Comparing catalogue (vG+2023)

# %%
df_vg =  pd.read_csv('Catalogues/NGC2539_vG2023+GaiaDR3.csv')
df_vg
# Out:
#                   GaiaDR3     RA_ICRS    DE_ICRS     Plx   pmRA   pmDE  \
# 0     5725183060454307840  122.543457 -13.441126  0.5316 -2.749 -0.215
# 1     5725182953073887360  122.514357 -13.457342  0.6788 -2.414  0.028
# 2     5725180723992144256  122.446022 -13.534858  0.7080 -2.336 -0.247
# 3     5725178696767530112  122.620965 -13.510299  0.6625 -2.193 -0.258
# 4     5725178314509097728  122.539048 -13.547586  0.7476 -1.777 -0.625
# ...                   ...         ...        ...     ...    ...    ...
# 1134  5725970276418851328  122.103406 -13.064577  0.7605 -2.301 -0.531
# 1135  5725112794788207744  122.846499 -13.754821  0.7201 -1.988 -0.638
# 1136  5725107980125916416  122.916747 -13.856385  0.6776 -2.218 -0.192
# 1137  5725191165050219392  122.131967 -13.494460  0.3708 -2.558 -0.637
# 1138  5725189279566943360  122.000996 -13.551925  0.7522 -2.359 -0.122
#
#            Gmag      BPmag      RPmag   Cluster  ...  E(BP-RP) b_E(BP-RP)_x  \
# 0     19.453873  19.289522  18.325554  NGC_2539  ...       NaN          NaN
# 1     18.965633  19.964792  17.986687  NGC_2539  ...    0.0486       0.0150
# 2     18.992800  19.908337  18.105816  NGC_2539  ...    0.0138       0.0043
# 3     18.503292  19.363157  17.563908  NGC_2539  ...    0.2539       0.2363
# 4     18.062864  18.826242  17.112633  NGC_2539  ...    0.1028       0.0777
# ...         ...        ...        ...       ...  ...       ...          ...
# 1134  13.934523  14.170032  13.552169  NGC_2539  ...    0.0923       0.0878
# 1135  17.717495  18.519274  16.835249  NGC_2539  ...    0.2831       0.2700
# 1136  15.150477  15.475309  14.663897  NGC_2539  ...    0.0460       0.0417
# 1137  19.609621  20.761806  18.539328  NGC_2539  ...       NaN          NaN
# 1138  15.937064  16.354637  15.356649  NGC_2539  ...    0.1135       0.1033
#
#       B_E(BP-RP)_xa      Lib     RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  \
# 0               NaN      NaN  122.543469 -13.441125   5.009369   3.603222
# 1            0.1002  PHOENIX  122.514368 -13.457342   3.510630   2.398008
# 2            0.0281    MARCS  122.446032 -13.534857   3.623407   2.351267
# 3            0.2768    MARCS  122.620975 -13.510297   2.765433   1.990795
# 4            0.1289  PHOENIX  122.539056 -13.547583   1.923987   1.365186
# ...             ...      ...         ...        ...        ...        ...
# 1134         0.0962        A  122.103416 -13.064574   0.297504   0.191861
# 1135         0.2987  PHOENIX  122.846508 -13.754818   1.612267   1.417754
# 1136         0.0515    MARCS  122.916757 -13.856384   0.470797   0.366977
# 1137            NaN      NaN  122.131979 -13.494457   5.168311   4.066477
# 1138         0.1223    MARCS  122.001007 -13.551925   0.568713   0.429626
#
#       RADEcorJ2000  angDist
# 0           0.0699      0.0
# 1           0.0564      0.0
# 2           0.0357      0.0
# 3           0.0404      0.0
# 4           0.0493      0.0
# ...            ...      ...
# 1134        0.0588      0.0
# 1135        0.0109      0.0
# 1136       -0.0176      0.0
# 1137       -0.1379      0.0
# 1138        0.0253      0.0
#
# [1139 rows x 149 columns]

# %%
jj, = np.where(df_vg.Pmemb >= 0.7)
dfvg = df_vg.iloc[jj]

# %%
dfvg
# Out:
#                   GaiaDR3     RA_ICRS    DE_ICRS     Plx   pmRA   pmDE  \
# 11    5725169724574250368  122.436369 -13.687641  0.7825 -2.457 -0.398
# 13    5725168079608466304  122.443245 -13.765486  0.7389 -2.559 -0.370
# 21    5725195086362592896  122.480864 -13.408580  0.7372 -2.286 -0.556
# 22    5725107915705369984  122.876573 -13.863225  0.8040 -2.290 -0.747
# 29    5724918868422661120  123.007680 -13.927760  0.8103 -2.426 -0.595
# ...                   ...         ...        ...     ...    ...    ...
# 1114  5725969932821520640  122.008902 -13.098581  0.8245 -2.080 -0.492
# 1123  5725956017127403648  122.250761 -13.170479  0.7394 -2.347 -0.421
# 1128  5725951241123812224  122.222086 -13.293557  0.8289 -2.344 -0.535
# 1131  5726426088409609600  123.504827 -13.744042  0.8378 -2.243 -0.433
# 1134  5725970276418851328  122.103406 -13.064577  0.7605 -2.301 -0.531
#
#            Gmag      BPmag      RPmag   Cluster  ...  E(BP-RP) b_E(BP-RP)_x  \
# 11    17.591800  18.290110  16.808563  NGC_2539  ...    0.1052       0.0894
# 13    14.012406  14.255021  13.619826  NGC_2539  ...    0.1246       0.1218
# 21    13.472965  13.666136  13.149684  NGC_2539  ...    0.0885       0.0840
# 22    15.763227  16.162367  15.196784  NGC_2539  ...    0.0146       0.0060
# 29    15.580099  15.963792  15.036696  NGC_2539  ...    0.0647       0.0564
# ...         ...        ...        ...       ...  ...       ...          ...
# 1114  17.025606  17.619530  16.305689  NGC_2539  ...    0.0362       0.0095
# 1123  14.926690  15.240170  14.442820  NGC_2539  ...    0.0476       0.0362
# 1128  17.370806  18.019985  16.611818  NGC_2539  ...    0.0586       0.0471
# 1131  17.197863  17.890827  16.414024  NGC_2539  ...    0.1149       0.0969
# 1134  13.934523  14.170032  13.552169  NGC_2539  ...    0.0923       0.0878
#
#       B_E(BP-RP)_xa      Lib     RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  \
# 11           0.1184    MARCS  122.436381 -13.687639   1.402404   1.034618
# 13           0.1275    MARCS  122.443256 -13.765484   0.274634   0.186572
# 21           0.0940    MARCS  122.480874 -13.408578   0.212803   0.163630
# 22           0.0236    MARCS  122.876584 -13.863222   0.654409   0.478973
# 29           0.0725    MARCS  123.007691 -13.927758   0.529302   0.490049
# ...             ...      ...         ...        ...        ...        ...
# 1114         0.0598  PHOENIX  122.008911 -13.098578   1.357902   0.901828
# 1123         0.0593    MARCS  122.250772 -13.170477   0.426359   0.282829
# 1128         0.0704  PHOENIX  122.222096 -13.293555   1.356928   0.943008
# 1131         0.1387  PHOENIX  123.504837 -13.744040   1.332593   1.539109
# 1134         0.0962        A  122.103416 -13.064574   0.297504   0.191861
#
#       RADEcorJ2000  angDist
# 11          0.0442      0.0
# 13          0.0871      0.0
# 21          0.0082      0.0
# 22         -0.0070      0.0
# 29         -0.1401      0.0
# ...            ...      ...
# 1114       -0.1079      0.0
# 1123        0.0948      0.0
# 1128        0.0388      0.0
# 1131       -0.2364      0.0
# 1134        0.0588      0.0
#
# [655 rows x 149 columns]

# %% [markdown]
# # 5 Populations

# %%
p1 = pd.read_csv('Catalogues/pop1_NGC2539_GMM3.csv')
p2 = pd.read_csv('Catalogues/pop2_NGC2539_GMM3.csv')
p3 = pd.read_csv('Catalogues/pop3_NGC2539_GMM3.csv')
p4 = pd.read_csv('Catalogues/pop4_NGC2539_GMM3.csv')
p5 = pd.read_csv('Catalogues/pop5_NGC2539_GMM3.csv')

# %% [markdown]
# ## Computing Completeness and Purity

# %% [markdown]
# ### Population 1

# %%
ra1 = p1.RAJ2000
dec1 = p1.DEJ2000

ra2 = dfvg.RAJ2000
dec2 = dfvg.DEJ2000

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p1.iloc[matched_idx_catalog1]
# Out:
#          RAJ2000    DEJ2000   pmRA   pmDE       Gmag     BP-RP     Plx  \
# 494   121.589293 -13.093309 -2.201 -0.411  12.731518  0.378699  0.7773
# 906   121.568572 -12.644397 -2.301 -0.411  16.337315  1.159345  0.7057
# 1327  122.034538 -12.683238 -2.225 -0.304  15.412107  1.009403  0.7361
# 1402  121.936630 -12.556276 -1.956 -0.347  13.159049  0.446623  0.6987
# 1416  121.910056 -12.451314 -2.317 -0.518  16.496590  1.065621  0.7763
# 1422  121.986930 -12.414451 -2.289 -0.518  15.343348  0.847955  0.7293
# 1545  121.959984 -12.327115 -2.610 -0.541  12.454536  0.327003  0.8121
# 1550  121.908635 -12.295745 -2.297 -0.653  15.023970  0.801169  0.7153
# 1582  121.553500 -12.334414 -2.235 -0.591  14.431812  0.689578  0.7795
# 1687  121.987003 -12.075527 -2.378 -0.808  14.231053  0.677933  0.7857
# 1693  122.125913 -12.096969 -2.163 -0.385  14.497416  0.678251  0.7248
# 1779  122.084513 -11.893045 -2.357 -0.348  17.198061  1.388130  0.7568
# 2150  122.369849 -11.763092 -2.345 -0.596  13.256223  0.458415  0.7174
#
#       cluster
# 89           0.0772    MARCS  121.908635 -12.295745   0.420460   0.258704
# 1086         0.0504    MARCS  121.553500 -12.334414   0.342254   0.263938
# 403          0.0588    MARCS  121.987003 -12.075527   0.310541   0.183848
# 429          0.0645    MARCS  122.125913 -12.096969   0.352639   0.216830
# 843          0.1173    MARCS  122.084513 -11.893045   1.104191   0.742859
# 538          0.1123    MARCS  122.369849 -11.763092   0.234162   0.172300
#
#       RADEcorJ2000  angDist
# 108         0.1474      0.0
# 175        -0.0818      0.0
# 549         0.1587      0.0
# 517         0.0247      0.0
# 553         0.0819      0.0
# 585         0.0607      0.0
# 93          0.1436      0.0
# 89          0.1416      0.0
# 1086       -0.1655      0.0
# 403         0.0440      0.0
# 429         0.1281      0.0
# 843         0.0456      0.0
# 538        -0.1448      0.0
#
# [13 rows x 149 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(p1.RAJ2000, p1.DEJ2000, s=1, c='grey')
ax.scatter(dfvg.RAJ2000, dfvg.DEJ2000, s=1, c='b')
ax.scatter(p1.iloc[matched_idx_catalog1].RAJ2000, p1.iloc[matched_idx_catalog1].DEJ2000, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
ax.set_ylim(-11.5,-14.2)
ax.set_xlim(121.2,124.5)
# Out:
# (121.2, 124.5)

# %%
dfvg_t = len(dfvg)
p1_t = len(p1.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p1_c = p1_t /dfvg_t
p1_c*100
# Out:
# 1.984732824427481

# %% [markdown]
# Pureness

# %%
p1_p = p1_t/len(p1)
p1_p*100
# Out:
# 0.5214600882470918

# %% [markdown]
# ### Population 2

# %%
ra1 = p2.RAJ2000
dec1 = p2.DEJ2000

ra2 = dfvg.RAJ2000
dec2 = dfvg.DEJ2000

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p2
# Out:
#          RAJ2000    DEJ2000   pmRA   pmDE       Gmag     BP-RP     Plx  \
# 0     120.836705 -12.094696 -1.244 -1.837  18.386425  1.442709  0.5912
# 1     120.821970 -12.089708 -3.211 -2.017  20.124277  1.666735  0.8475
# 2     120.835819 -12.034627 -0.763 -1.769  16.235035  1.042976  0.6337
# 3     120.966764 -11.983713 -2.259 -0.310  20.102997  2.181265  0.7669
# 4     120.904819 -11.989479 -2.238 -2.179  17.254555  1.449751  0.7753
# ...          ...        ...    ...    ...        ...       ...     ...
# 605         0.0169      0.0
# 555        -0.0709      0.0
# 557        -0.1944      0.0
# 409        -0.1043      0.0
# 120        -0.1344      0.0
# 97          0.1469      0.0
#
# [23 rows x 149 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(p2.RAJ2000, p2.DEJ2000, s=1, c='grey')
ax.scatter(dfvg.RAJ2000, dfvg.DEJ2000, s=1, c='b')
ax.scatter(p2.iloc[matched_idx_catalog1].RAJ2000, p2.iloc[matched_idx_catalog1].DEJ2000, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
ax.set_ylim(-11.5,-14.2)
ax.set_xlim(121.2,124.5)
# Out:
# (121.2, 124.5)

# %%
dfvg_t = len(dfvg)
p2_t = len(p2.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p2_c = p2_t /dfvg_t
p2_c*100
# Out:
# 3.5114503816793894

# %% [markdown]
# Pureness

# %%
p2_p = p2_t/len(p2)
p2_p*100
# Out:
# 0.6711409395973155

# %% [markdown]
# ### Population 3

# %%
ra1 = p3.RAJ2000
dec1 = p3.DEJ2000

ra2 = dfvg.RAJ2000
dec2 = dfvg.DEJ2000

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p3.iloc[matched_idx_catalog1]
# Out:
#         RAJ2000    DEJ2000   pmRA   pmDE       Gmag     BP-RP     Plx  cluster
# 0    122.480874 -13.408578 -2.286 -0.556  13.472965  0.516452  0.7372        2
# 1    122.414207 -13.314847 -2.311 -0.600  13.363639  0.609845  0.7725        2
# 2    122.222096 -13.293555 -2.344 -0.535  17.370806  1.408167  0.8289        2
# 3    122.250772 -13.170477 -2.347 -0.421  14.926690  0.797351  0.7394        2
# 4    122.103416 -13.064574 -2.301 -0.531  13.934523  0.617864  0.7605        2
# ..          ...        ...    ...    ...        ...       ...     ...      ...
# 577  122.774611 -12.305778 -2.374 -0.748  14.581053  0.750966  0.7523        2
# 578  122.749552 -12.298490 -2.276 -0.582  16.656437  1.181709  0.7921        2
# 579  122.746991 -12.238201 -2.327 -0.620  16.202570  1.042841  0.7213        2
# 580  122.678540 -12.205106 -2.376 -0.585  15.679736  0.965592  0.7160        2
# 581  122.761971 -12.170666 -2.344 -0.540  13.687578  0.578143  0.7684        2
#
# [536 rows x 8 columns]

# %%
dfvg.iloc[matched_idx_catalog2]
# Out:
#                   GaiaDR3     RA_ICRS    DE_ICRS     Plx   pmRA   pmDE  \
fig, ax = plt.subplots()

ax.scatter(p3.RAJ2000, p3.DEJ2000, s=1, c='grey')
ax.scatter(dfvg.RAJ2000, dfvg.DEJ2000, s=1, c='b')
ax.scatter(p3.iloc[matched_idx_catalog1].RAJ2000, p3.iloc[matched_idx_catalog1].DEJ2000, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
ax.set_ylim(-11.5,-14.2)
ax.set_xlim(121.2,124.5)
# Out:
# (121.2, 124.5)

# %%
dfvg_t = len(dfvg)
p3_t = len(p3.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p3_c = p3_t /dfvg_t
p3_c*100
# Out:
# 81.83206106870229

# %% [markdown]
# Pureness

# %%
p3_p = p3_t/len(p3)
p3_p*100
# Out:
# 92.09621993127148

# %% [markdown]
# ### Population 4

# %%
ra1 = p4.RAJ2000
dec1 = p4.DEJ2000

ra2 = dfvg.RAJ2000
dec2 = dfvg.DEJ2000

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p4.iloc[matched_idx_catalog1]
# Out:
#          RAJ2000    DEJ2000   pmRA   pmDE       Gmag     BP-RP     Plx  \
# 587   123.007691 -13.927758 -2.426 -0.595  15.580099  0.927096  0.8103
# 1184  122.876584 -13.863222 -2.290 -0.747  15.763227  0.965583  0.8040
# 1212  122.516385 -13.965905 -2.239 -0.433  17.050293  1.205120  0.7145
# 1235  122.556166 -13.847287 -2.152 -0.728  15.925107  0.902498  0.7071
# 1272  122.623236 -13.760112 -2.357 -0.526  17.152250  1.338465  0.7557
# 1279  122.565709 -13.713057 -2.385 -0.689  16.258614  1.038034  0.7444
# 1482  122.443256 -13.765484 -2.559 -0.370  14.012406  0.635195  0.7389
# 1490  122.436381 -13.687639 -2.457 -0.398  17.591800  1.481546  0.7825
# 1975  121.773480 -13.476245 -2.319 -0.410  16.195013  1.040184  0.7004
# 2039  121.805420 -13.405955 -2.106 -0.381  15.765438  0.843130  0.7624
# 2340  122.875046 -13.668123 -2.075 -0.386  17.558283  1.399096  0.7324
# 2351  122.818787 -13.543956 -1.990 -0.498  15.771508  0.918681  0.7728
#
#       cluster
# 587         3
# 1184        3
# 1212        3
# 1235        3
# 1272        3
# 1279        3
# 1482        3
# 1490        3
# 1975        3
# 2039        3
# 2340        3
# 2351        3

# %%
dfvg.iloc[matched_idx_catalog2]
# Out:
#                   GaiaDR3     RA_ICRS    DE_ICRS     Plx   pmRA   pmDE  \
# 29         -0.1401      0.0
# 22         -0.0070      0.0
# 1110        0.0169      0.0
# 1106       -0.0797      0.0
# 1100       -0.0369      0.0
# 1099       -0.0433      0.0
# 13          0.0871      0.0
# 11          0.0442      0.0
# 1091        0.0767      0.0
# 1111        0.0846      0.0
# 136        -0.0721      0.0
# 72         -0.0322      0.0
#
# [12 rows x 149 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(p4.RAJ2000, p4.DEJ2000, s=1, c='grey')
ax.scatter(dfvg.RA_ICRS, dfvg.DE_ICRS, s=1, c='b')
ax.scatter(p4.iloc[matched_idx_catalog1].RAJ2000, p4.iloc[matched_idx_catalog1].DEJ2000, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
ax.set_ylim(-11.5,-14.2)
ax.set_xlim(121.2,124.5)
# Out:
# (121.2, 124.5)

# %%
dfvg_t = len(dfvg)
p4_t = len(p4.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p4_c = p4_t /dfvg_t
p4_c*100
# Out:
# 1.8320610687022902

# %% [markdown]
# Pureness

# %%
p4_p = p4_t/len(p4)
p4_p*100
# Out:
# 0.4977187888842804

# %% [markdown]
# ### Population 5

# %%
ra1 = p5.RAJ2000
dec1 = p5.DEJ2000

ra2 = dfvg.RAJ2000
dec2 = dfvg.DEJ2000

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p5.iloc[matched_idx_catalog1]
# Out:
#          RAJ2000    DEJ2000   pmRA   pmDE       Gmag     BP-RP     Plx  \
# 73    123.621688 -14.010179 -2.411 -0.372  14.458142  0.705700  0.7870
# 360   123.708779 -13.305395 -2.255 -0.542  15.023931  0.814781  0.7145
# 569   124.003075 -13.136115 -2.335 -0.494  15.850763  0.962978  0.7899
# 701   123.252097 -13.586993 -2.338 -0.238  12.331991  0.304743  0.6999
# 734   123.185856 -13.427786 -1.986 -0.595  12.940250  0.482623  0.7488
# 806   123.198750 -13.358569 -2.266 -0.145  14.299912  0.671442  0.7143
# 857   123.431666 -13.095293 -2.427 -0.443  15.969254  1.027783  0.7861
# 983   123.005507 -12.979301 -2.719 -0.319  13.510445  0.636224  0.7587
# 994   123.305812 -12.974520 -2.125 -0.474  16.040089  0.958479  0.6588
# 1004  123.123719 -12.990305 -2.069 -0.199  14.193339  0.647512  0.7158
# 1212  124.105766 -12.872159 -2.291 -0.531  10.635257  0.266273  0.7138
# 345         0.0179  PHOENIX  122.569796 -12.481906   1.350021   1.165072
# 568         0.0791    MARCS  123.375083 -12.316849   1.029064   0.993149
# 569         0.0063  PHOENIX  123.116095 -12.276916   0.784540   0.733339
# 578         0.0502  PHOENIX  123.045284 -12.185986   0.870358   0.902399
# 579         0.0460    MARCS  123.129395 -12.171046   0.433257   0.429606
# 119         0.0609    MARCS  122.998586 -12.039033   0.832881   0.812169
# 519         0.0728    MARCS  122.769471 -11.629917   0.552580   0.587360
#
#      RADEcorJ2000  angDist
# 416       -0.2867      0.0
# 116       -0.2130      0.0
# 122       -0.2495      0.0
# 125       -0.2651      0.0
# 68        -0.2797      0.0
# 56        -0.3556      0.0
# 47        -0.3983      0.0
# 995       -0.4654      0.0
# 205       -0.2887      0.0
# 763       -0.2146      0.0
# 970       -0.3203      0.0
# 505       -0.1197      0.0
# 640        0.2015      0.0
# 420       -0.0624      0.0
# 170       -0.1913      0.0
# 345       -0.1579      0.0
# 568       -0.1192      0.0
# 569       -0.2520      0.0
# 578       -0.2821      0.0
# 579       -0.2223      0.0
# 119       -0.2199      0.0
# 519       -0.2028      0.0
#
# [22 rows x 149 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(p5.RAJ2000, p5.DEJ2000, s=1, c='grey')
ax.scatter(dfvg.RAJ2000, dfvg.DEJ2000, s=1, c='b')
ax.scatter(p5.iloc[matched_idx_catalog1].RAJ2000, p5.iloc[matched_idx_catalog1].DEJ2000, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
ax.set_ylim(-11.5,-14.2)
ax.set_xlim(121.2,124.5)
# Out:
# (121.2, 124.5)

# %%
dfvg_t = len(dfvg)
p5_t = len(p5.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p5_c = p5_t /dfvg_t
p5_c*100
# Out:
# 3.3587786259541987

# %% [markdown]
# Pureness

# %%
p5_p = p5_t/len(p5)
p5_p*100
# Out:
# 0.6842923794712287

# %% [markdown]
# ## Analyzing

# %%
import seaborn as sns

# Dados simulados: completude e pureza por cluster
clusters = [1, 2, 3, 4, 5]
completeness = [p1_c, p2_c, p3_c, p4_c, p5_c]  # Exemplo de completude
purity = [p1_p, p2_p, p3_p, p4_p, p5_p]  # Exemplo de pureza

# Bar plot
x = range(len(clusters))
plt.bar(x, completeness, width=0.4, label="Completeness", alpha=0.8, align='center')
plt.bar(x, purity, width=0.4, label="Purity", alpha=0.8, align='edge')

plt.xticks(x, [f"Cluster {c}" for c in clusters])
plt.ylabel("Value")
plt.title("Completeness and Purity by Cluster")
plt.legend()
plt.show()

# %%
ra1 = p1_2p.RA_ICRS
dec1 = p1_2p.DE_ICRS

ra2 = dfvg.RA_ICRS
dec2 = dfvg.DE_ICRS

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p1_2p.iloc[matched_idx_catalog1]
# Out:
#          RA_ICRS    DE_ICRS               Source  e_RA_ICRS  e_DE_ICRS  \
# 729   123.007680 -13.927760  5724918868422661120     0.0225     0.0210
# 1197  122.876573 -13.863225  5725107915705369984     0.0249     0.0203
# 1218  122.516375 -13.965907  5725113481983114240     0.0463     0.0348
# 1240  122.556156 -13.847291  5725116849237274752     0.0244     0.0198
# 1270  122.623225 -13.760115  5725126401244507904     0.0488     0.0377
# ...          ...        ...                  ...        ...        ...
# 6424  121.986992 -12.075530  5727777839175515520     0.0126     0.0085
# 6430  122.125904 -12.096970  5727779797680542464     0.0141     0.0096
# 6507  122.084503 -11.893047  5727798523739919360     0.0471     0.0336
# 6815  122.369838 -11.763095  5727883426649794560     0.0098     0.0077
# 6912  122.769462 -11.629920  5727912494988318336     0.0247     0.0231
#
#          Plx   e_Plx     PM   pmRA  e_pmRA  ...       Gmag      BPmag  \
# 729   0.8103  0.0328  2.498 -2.426   0.033  ...  15.580099  15.963792
# 1197  0.8040  0.0383  2.409 -2.290   0.041  ...  15.763227  16.162367
# 1218  0.7145  0.0745  2.281 -2.239   0.069  ...  17.050293  17.589607
# 1240  0.7071  0.0384  2.272 -2.152   0.035  ...  15.925107  16.289055
# 1270  0.7557  0.0697  2.415 -2.357   0.069  ...  17.152250  17.761162
# ...      ...     ...    ...    ...     ...  ...        ...        ...
# 6424  0.7857  0.0186  2.512 -2.378   0.019  ...  14.231053  14.491918
# 6430  0.7248  0.0215  2.197 -2.163   0.022  ...  14.497416  14.759340
# 6507  0.7568  0.0697  2.383 -2.357   0.069  ...  17.198061  17.843935
# 6815  0.7174  0.0149  2.419 -2.345   0.015  ...  13.256223  13.424639
# 6912  0.7955  0.0327  2.153 -2.062   0.034  ...  15.634084  16.025911
#
#           RPmag     BP-RP     RV       ELAT     RAJ2000    DEJ2000  Plx_corr  \
# 729   15.036696  0.927096    NaN -32.997611  123.007691 -13.927758  0.852579
# 1197  15.196784  0.965583    NaN -32.968078  122.876584 -13.863222  0.846286
# 1218  16.384487  1.205120    NaN -33.156968  122.516385 -13.965905  0.744836
# 1240  15.386557  0.902498    NaN -33.032424  122.556166 -13.847287  0.748479
# 1270  16.422697  1.338465    NaN -32.931504  122.623236 -13.760112  0.785536
# ...         ...       ...    ...        ...         ...        ...       ...
# 6424  13.813985  0.677933  32.14 -31.456736  121.987003 -12.075527  0.828046
# 6430  14.081089  0.678251  34.35 -31.443894  122.125913 -12.096969  0.767314
# 6507  16.455805  1.388130    NaN -31.256342  122.084513 -11.893045  0.785921
# 6815  12.966224  0.458415    NaN -31.061217  122.369849 -11.763092  0.759958
# 6912  15.070681  0.955231    NaN -30.834555  122.769471 -11.629917  0.838047
#
#       cluster
# 729         0
# 1197        0
# 1218        0
# 1240        0
# 1270        0
# ...       ...
# 6424        0
# 6430        0
# 6507        0
# 6815        0
# 6912        0
#
# [596 rows x 26 columns]

# %%
dfvg.iloc[matched_idx_catalog2]
# Out:
#                   GaiaDR3     RA_ICRS    DE_ICRS     Plx   pmRA   pmDE  \
# 1029  5724918868422661120  123.007680 -13.927760  0.8103 -2.426 -0.595
# 1022  5725107915705369984  122.876573 -13.863225  0.8040 -2.290 -0.747
# 971   5725113481983114240  122.516375 -13.965907  0.7145 -2.239 -0.433
# 967   5725116849237274752  122.556156 -13.847291  0.7071 -2.152 -0.728
# 961   5725126401244507904  122.623225 -13.760115  0.7557 -2.357 -0.526
# ...                   ...         ...        ...     ...    ...    ...
# 264   5727777839175515520  121.986992 -12.075530  0.7857 -2.378 -0.808
# 290   5727779797680542464  122.125904 -12.096970  0.7248 -2.163 -0.385
# 704   5727798523739919360  122.084503 -11.893047  0.7568 -2.357 -0.348
# 399   5727883426649794560  122.369838 -11.763095  0.7174 -2.345 -0.596
# 380   5727912494988318336  122.769462 -11.629920  0.7955 -2.062 -0.620
#
#            Gmag      BPmag      RPmag   Cluster  Pmemb
# 1029  15.580099  15.963792  15.036696  NGC_2539   1.00
# 1022  15.763227  16.162367  15.196784  NGC_2539   0.98
# 971   17.050293  17.589607  16.384487  NGC_2539   0.74
# 967   15.925107  16.289055  15.386557  NGC_2539   0.83
# 961   17.152250  17.761162  16.422697  NGC_2539   0.96
# ...         ...        ...        ...       ...    ...
# 264   14.231053  14.491918  13.813985  NGC_2539   1.00
# 290   14.497416  14.759340  14.081089  NGC_2539   1.00
# 704   17.198061  17.843935  16.455805  NGC_2539   0.87
# 399   13.256223  13.424639  12.966224  NGC_2539   1.00
# 380   15.634084  16.025911  15.070681  NGC_2539   0.80
#
# [596 rows x 11 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(p1_2p.RA_ICRS, p1_2p.DE_ICRS, s=1, c='grey')
ax.scatter(dfvg.RA_ICRS, dfvg.DE_ICRS, s=1, c='b')
ax.scatter(p1_2p.iloc[matched_idx_catalog1].RA_ICRS, p1_2p.iloc[matched_idx_catalog1].DE_ICRS, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
ax.set_ylim(-11.5,-14.2)
ax.set_xlim(121.2,124.5)
# Out:
# (121.2, 124.5)

# %%
dfvg_t = len(dfvg)
p1_2p_t = len(p1_2p.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p1_2p_c = p1_2p_t /dfvg_t
p1_2p_c*100
# Out:
# 90.99236641221374

# %% [markdown]
# Pureness

# %%
p1_2p_p = p1_2p_t/len(p1_2p)
p1_2p_p*100
# Out:
# 7.763449264035431

# %%
ra1 = p2_2p.RA_ICRS
dec1 = p2_2p.DE_ICRS

ra2 = dfvg.RA_ICRS
dec2 = dfvg.DE_ICRS

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p2_2p.iloc[matched_idx_catalog1]
# Out:
#          RA_ICRS    DE_ICRS               Source  e_RA_ICRS  e_DE_ICRS  \
# 2574  122.921398 -13.185993  5726694747202461312     0.0559     0.0568
# 2589  122.425772 -13.241586  5726702409422712192     0.0697     0.0536
# 2608  122.595976 -13.031000  5726711690850248704     0.0512     0.0407
# 3142  122.547817 -12.972002  5727463511987435904     0.0968     0.0712
# 3145  122.621274 -12.911557  5727465612232588928     0.0736     0.0637
# 3152  122.557252 -12.840559  5727469254364865024     0.0329     0.0251
# 3154  122.493979 -12.845428  5727469765460098560     0.1364     0.1081
# 3205  122.690985 -12.804562  5727490145085719936     0.0655     0.0594
# 3209  122.719631 -12.805480  5727491588194718336     0.0588     0.0519
# 3213  122.624003 -12.807470  5727492859505082624     0.0467     0.0391
#
#          Plx   e_Plx     PM   pmRA  e_pmRA  ...       Gmag      BPmag  \
# 2574  0.6139  0.0780  2.329 -2.260   0.084  ...  17.271206  17.964739
# 2589  0.6523  0.1068  2.509 -2.426   0.105  ...  17.896448  18.671953
# 2608  0.6404  0.0811  2.347 -2.301   0.074  ...  17.062359  17.641851
# 3142  0.6307  0.1485  2.331 -2.296   0.147  ...  18.121515  18.958378
# 3145  0.6394  0.1189  2.387 -2.359   0.114  ...  17.720638  18.434364
# 3152  0.6488  0.0458  2.485 -2.475   0.047  ...  16.412067  16.879095
# 3154  0.6333  0.2040  2.351 -2.272   0.194  ...  18.827095  19.748213
# 3205  0.6499  0.0940  2.421 -2.346   0.095  ...  17.579407  18.285118
# 3209  0.6471  0.0780  2.373 -2.327   0.083  ...  17.026710  17.570848
# 3213  0.6429  0.0652  2.367 -2.307   0.069  ...  17.027517  17.609938
#
#           RPmag     BP-RP  RV       ELAT     RAJ2000    DEJ2000  Plx_corr  \
# 2574  16.480680  1.484058 NaN -32.302333  122.921408 -13.185990  0.643280
# 2589  17.053247  1.618706 NaN -32.478802  122.425783 -13.241584  0.679101
# 2608  16.351288  1.290564 NaN -32.233123  122.595987 -13.030998  0.670546
# 3142  17.246717  1.711660 NaN -32.187922  122.547828 -12.972000  0.656476
# 3145  16.915213  1.519152 NaN -32.111331  122.621285 -12.911555  0.667010
# 3152  15.787485  1.091610 NaN -32.058422  122.557264 -12.840558  0.681092
# 3154  17.843770  1.904444 NaN -32.078703  122.493990 -12.845425  0.655229
# 3205  16.796236  1.488882 NaN -31.990612  122.690996 -12.804559  0.678229
# 3209  16.323402  1.247446 NaN -31.984422  122.719641 -12.805478  0.677407
# 3213  16.332210  1.277727 NaN -32.009957  122.624013 -12.807467  0.673165
#
#       cluster
# 2574        1
# 2589        1
# 2608        1
# 3142        1
# 3145        1
# 3152        1
# 3154        1
# 3205        1
# 3209        1
# 3213        1
#
# [10 rows x 26 columns]

# %%
dfvg.iloc[matched_idx_catalog2]
# Out:
#                  GaiaDR3     RA_ICRS    DE_ICRS     Plx   pmRA   pmDE  \
# 321  5726694747202461312  122.921398 -13.185993  0.6139 -2.260 -0.563
# 307  5726702409422712192  122.425772 -13.241586  0.6523 -2.426 -0.640
# 297  5726711690850248704  122.595976 -13.031000  0.6404 -2.301 -0.463
# 481  5727463511987435904  122.547817 -12.972002  0.6307 -2.296 -0.400
# 574  5727465612232588928  122.621274 -12.911557  0.6394 -2.359 -0.363
# 557  5727469254364865024  122.557252 -12.840559  0.6488 -2.475 -0.222
# 863  5727469765460098560  122.493979 -12.845428  0.6333 -2.272 -0.604
# 714  5727490145085719936  122.690985 -12.804562  0.6499 -2.346 -0.597
# 812  5727491588194718336  122.719631 -12.805480  0.6471 -2.327 -0.465
# 790  5727492859505082624  122.624003 -12.807470  0.6429 -2.307 -0.527
#
#           Gmag      BPmag      RPmag   Cluster  Pmemb
# 321  17.271206  17.964739  16.480680  NGC_2539   0.78
# 307  17.896448  18.671953  17.053247  NGC_2539   0.73
# 297  17.062359  17.641851  16.351288  NGC_2539   0.90
# 481  18.121515  18.958378  17.246717  NGC_2539   0.71
# 574  17.720638  18.434364  16.915213  NGC_2539   0.72
# 557  16.412067  16.879095  15.787485  NGC_2539   0.91
# 863  18.827095  19.748213  17.843770  NGC_2539   0.70
# 714  17.579407  18.285118  16.796236  NGC_2539   0.96
# 812  17.026710  17.570848  16.323402  NGC_2539   0.96
# 790  17.027517  17.609938  16.332210  NGC_2539   0.96

# %%
fig, ax = plt.subplots()

ax.scatter(p2_2p.RA_ICRS, p2_2p.DE_ICRS, s=1, c='grey')
ax.scatter(dfvg.RA_ICRS, dfvg.DE_ICRS, s=1, c='b')
ax.scatter(p2_2p.iloc[matched_idx_catalog1].RA_ICRS, p2_2p.iloc[matched_idx_catalog1].DE_ICRS, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
ax.set_ylim(-11.5,-14.2)
ax.set_xlim(121.2,124.5)
# Out:
# (121.2, 124.5)

# %%
dfvg_t = len(dfvg)
p2_2p_t = len(p2_2p.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p2_2p_c = p2_2p_t /dfvg_t
p2_2p_c*100
# Out:
# 1.5267175572519083

# %% [markdown]
# Pureness

# %%
p2_2p_p = p2_2p_t/len(p2_2p)
p2_2p_p*100
# Out:
# 0.21853146853146854
