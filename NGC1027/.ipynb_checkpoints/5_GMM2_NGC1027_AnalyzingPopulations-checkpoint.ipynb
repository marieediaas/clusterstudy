# %%
import numpy as np
import pandas as pd
from astropy.io import ascii
from astropy.coordinates import SkyCoord
from astropy import units as u
import os
import matplotlib.pyplot as plt
import mpl_scatter_density

# %% [markdown]
# # Comparing catalogue (vG+2023)

# %%
df_vg =  pd.read_csv('Catalogues/NGC1027_vG2023+GaiaDR3.csv')
df_vg
# Out:
#        Cluster             GaiaDR3    RA_ICRS    DE_ICRS     Plx   pmRA  \
# 0     NGC_1027  465694821355155328  40.505659  61.784374  0.8964 -1.773
# 1     NGC_1027  465694748331683200  40.523624  61.774185  0.9010 -1.622
# 2     NGC_1027  465694683916216192  40.469041  61.767109  0.8540 -1.558
# 3     NGC_1027  465694610893071872  40.502789  61.752454  1.0832 -1.671
# 4     NGC_1027  465694546477250432  40.544690  61.776256  0.9628 -1.686
# ...        ...                 ...        ...        ...     ...    ...
# 1375  NGC_1027  465695474182156288  40.406755  61.776293  0.7598 -2.144
# 1376  NGC_1027  465695435526822656  40.459302  61.776889  0.9625 -1.842
# 1377  NGC_1027  465695126289128576  40.340698  61.742587  0.6292 -1.685
# 1378  NGC_1027  465695096222913152  40.387508  61.768844  0.3626 -1.220
# 1379  NGC_1027  465694855715262976  40.385405  61.715856  0.9083 -1.871
#
#        pmDE       Gmag      BPmag      RPmag  ...  E(BP-RP) b_E(BP-RP)_x  \
# 0     2.155  14.814943  15.274859  14.164726  ...    0.3645       0.3534
# 1     2.198  17.604593  18.443653  16.716528  ...    0.5752       0.5552
# 2     2.617  11.923204  12.138940  11.557860  ...    0.6047       0.5997
# 3     2.008  17.968418  18.876163  17.032963  ...    0.4264       0.4069
# 4     2.204  17.046154  17.778336  16.227764  ...    0.3364       0.3138
# ...     ...        ...        ...        ...  ...       ...          ...
# 1375  2.240  20.454760  21.504877  19.255125  ...       NaN          NaN
# 1376  1.912  17.249964  17.985037  16.378658  ...    0.3898       0.3664
# 1377  2.128  19.259914  20.094313  18.372610  ...       NaN          NaN
# 1378  2.507  20.064852  21.051865  18.944124  ...       NaN          NaN
# 1379  2.231  13.999979  14.375842  13.446248  ...    0.6581       0.6335
#
#       B_E(BP-RP)_xa      Lib    RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  \
# 0            0.3740    MARCS  40.505676  61.784365   0.326353   0.357943
# 1            0.5943    MARCS  40.523639  61.774175   1.399436   1.442121
# 2            0.6143        A  40.469056  61.767097   0.239440   0.276221
# 3            0.4445  PHOENIX  40.502805  61.752445   1.819094   1.953410
# 4            0.3570  PHOENIX  40.544705  61.776246   1.001668   1.054554
# ...             ...      ...        ...        ...        ...        ...
# 1375            NaN      NaN  40.406775  61.776283  10.129286  10.781652
# 1376         0.4093  PHOENIX  40.459319  61.776881   1.298300   1.377348
# 1377            NaN      NaN  40.340714  61.742578   4.578806   5.166427
# 1378            NaN      NaN  40.387520  61.768833   8.462630   8.415401
# 1379         0.6687        A  40.385422  61.715846   0.249937   0.293393
#
#       RADEcorJ2000  angDist
# 0          -0.0824      0.0
# 1          -0.1402      0.0
# 2          -0.0846      0.0
# 3          -0.1343      0.0
# 4          -0.1104      0.0
# ...            ...      ...
# 1375       -0.1126      0.0
# 1376       -0.1684      0.0
# 1377       -0.2178      0.0
# 1378        0.0792      0.0
# 1379       -0.0907      0.0
#
# [1380 rows x 149 columns]

# %%
jj, = np.where(df_vg.Pmemb >= 0.7)
dfvg = df_vg.iloc[jj]

# %%
dfvg
# Out:
#        Cluster             GaiaDR3    RA_ICRS    DE_ICRS     Plx   pmRA  \
# 0     NGC_1027  465694821355155328  40.505659  61.784374  0.8964 -1.773
# 1     NGC_1027  465694748331683200  40.523624  61.774185  0.9010 -1.622
# 2     NGC_1027  465694683916216192  40.469041  61.767109  0.8540 -1.558
# 3     NGC_1027  465694610893071872  40.502789  61.752454  1.0832 -1.671
# 4     NGC_1027  465694546477250432  40.544690  61.776256  0.9628 -1.686
# ...        ...                 ...        ...        ...     ...    ...
# 1372  NGC_1027  465699421256538368  40.269906  61.848165  0.9031 -1.868
# 1373  NGC_1027  465699215097697664  40.361267  61.884989  0.8797 -1.744
# 1374  NGC_1027  465695474190193408  40.427435  61.781116  0.7913 -1.737
# 1376  NGC_1027  465695435526822656  40.459302  61.776889  0.9625 -1.842
# 1379  NGC_1027  465694855715262976  40.385405  61.715856  0.9083 -1.871
#
#        pmDE       Gmag      BPmag      RPmag  ...  E(BP-RP) b_E(BP-RP)_x  \
# 0     2.155  14.814943  15.274859  14.164726  ...    0.3645       0.3534
# 1     2.198  17.604593  18.443653  16.716528  ...    0.5752       0.5552
# 2     2.617  11.923204  12.138940  11.557860  ...    0.6047       0.5997
# 3     2.008  17.968418  18.876163  17.032963  ...    0.4264       0.4069
# 4     2.204  17.046154  17.778336  16.227764  ...    0.3364       0.3138
# ...     ...        ...        ...        ...  ...       ...          ...
# 1372  1.933  17.708502  18.587675  16.822248  ...    0.4368       0.3484
# 1373  2.062  16.665634  17.330374  15.860227  ...    0.5042       0.4890
# 1374  2.134  16.822556  17.511656  16.019714  ...    0.6440       0.6199
# 1376  1.912  17.249964  17.985037  16.378658  ...    0.3898       0.3664
# 1379  2.231  13.999979  14.375842  13.446248  ...    0.6581       0.6335
#
#       B_E(BP-RP)_xa      Lib    RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  \
# 0            0.3740    MARCS  40.505676  61.784365   0.326353   0.357943
# 1            0.5943    MARCS  40.523639  61.774175   1.399436   1.442121
# 2            0.6143        A  40.469056  61.767097   0.239440   0.276221
# 3            0.4445  PHOENIX  40.502805  61.752445   1.819094   1.953410
# 4            0.3570  PHOENIX  40.544705  61.776246   1.001668   1.054554
# ...             ...      ...        ...        ...        ...        ...
# 1372         0.4884  PHOENIX  40.269923  61.848156   1.550565   1.533550
# 1373         0.5181    MARCS  40.361283  61.884980   0.833605   0.912919
# 1374         0.6546  PHOENIX  40.427452  61.781107   0.928986   0.960028
# 1376         0.4093  PHOENIX  40.459319  61.776881   1.298300   1.377348
# 1379         0.6687        A  40.385422  61.715846   0.249937   0.293393
#
#       RADEcorJ2000  angDist
# 0          -0.0824      0.0
# 1          -0.1402      0.0
# 2          -0.0846      0.0
# 3          -0.1343      0.0
# 4          -0.1104      0.0
# ...            ...      ...
# 1372       -0.1668      0.0
# 1373       -0.1607      0.0
# 1374       -0.1326      0.0
# 1376       -0.1684      0.0
# 1379       -0.0907      0.0
#
# [597 rows x 149 columns]

# %% [markdown]
# # 5 Populations

# %%
p1 = pd.read_csv('Catalogues/pop1_NGC1027_GMM2.csv')
p2 = pd.read_csv('Catalogues/pop2_NGC1027_GMM2.csv')
p3 = pd.read_csv('Catalogues/pop3_NGC1027_GMM2.csv')
p4 = pd.read_csv('Catalogues/pop4_NGC1027_GMM2.csv')
p5 = pd.read_csv('Catalogues/pop5_NGC1027_GMM2.csv')

# %% [markdown]
# ## Computing Completeness and Purity

# %% [markdown]
# ### Population 1

# %%
ra1 = p1.RAJ2000
dec1 = p1.DEJ2000

ra2 = dfvg.RAJ2000
dec2 = dfvg.DEJ2000

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p1.iloc[matched_idx_catalog1]
# Out:
#         RAJ2000    DEJ2000   pmRA   pmDE       Gmag     BP-RP     Plx  cluster
# 147   41.773842  60.540364 -1.799  2.160  17.921892  1.896875  0.8545        0
# 163   41.391990  60.440964 -1.793  1.868  15.092919  1.412945  0.8665        0
# 184   41.760699  60.667437 -1.459  2.020  15.022243  1.328855  0.9060        0
# 191   41.971382  60.869417 -1.530  2.133  13.546622  0.857985  0.8965        0
# 197   41.851700  60.892318 -1.809  1.878  12.826741  0.889601  0.9197        0
# ...         ...        ...    ...    ...        ...       ...     ...      ...
# 1529  41.991470  62.738418 -1.732  2.268  16.083628  1.326920  0.9009        0
# 1582  41.114905  62.905420 -1.936  2.048   8.369972  1.432346  0.9308        0
# 1597  40.787309  63.076058 -1.898  2.113  16.967535  1.562469  0.8373        0
# 1686  38.075178  62.268490 -1.970  2.068  14.957641  1.144249  0.8460        0
# 1693  37.636518  62.354817 -1.879  2.069  15.347439  1.213315  0.8722        0
#
# [115 rows x 8 columns]

# %%
dfvg.iloc[matched_idx_catalog2]
# Out:
#       Cluster             GaiaDR3    RA_ICRS    DE_ICRS     Plx   pmRA   pmDE  \
# 779  NGC_1027  464776037646911104  41.773826  60.540374  0.8545 -1.799  2.160
# 859  NGC_1027  464797963461759488  41.391974  60.440972  0.8665 -1.793  1.868
# 687  NGC_1027  464824798418117120  41.760686  60.667446  0.9060 -1.459  2.020
# 669  NGC_1027  464833766309733248  41.971368  60.869426  0.8965 -1.530  2.133
# 673  NGC_1027  464836652527754368  41.851684  60.892326  0.9197 -1.809  1.878
# ..        ...                 ...        ...        ...     ...    ...    ...
# 465  NGC_1027  467345360106608000  41.991454  62.738428  0.9009 -1.732  2.268
# 452  NGC_1027  467535884855567872  41.114886  62.905429  0.9308 -1.936  2.048
# 83   NGC_1027  467553236523330816  40.787290  63.076067  0.8373 -1.898  2.113
# 540  NGC_1027  513984032015800064  38.075159  62.268499  0.8460 -1.970  2.068
# 575  NGC_1027  513994855333356032  37.636500  62.354826  0.8722 -1.879  2.069
#
#           Gmag      BPmag      RPmag  ...  E(BP-RP) b_E(BP-RP)_x  \
# 779  17.921892  18.853360  16.956484  ...    0.4450       0.4032
# 859  15.092919  15.710403  14.297459  ...    1.0850       1.0804
# 687  15.022243  15.609508  14.280652  ...    0.9842       0.9744
# 669  13.546622  13.889764  13.031779  ...    0.8384       0.8376
# 673  12.826741  13.182690  12.293089  ...       NaN          NaN
# ..         ...        ...        ...  ...       ...          ...
# 465  16.083628  16.674650  15.347731  ...    0.4250       0.4146
# 452   8.369972   9.017055   7.584709  ...       NaN          NaN
# 83   16.967535  17.682224  16.119755  ...    0.4930       0.4739
# 540  14.957641  15.442095  14.297846  ...    0.6394       0.6258
# 575  15.347439  15.870675  14.657360  ...    0.5721       0.5684
#
#      B_E(BP-RP)_xa      Lib    RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  \
# 779         0.5247  PHOENIX  41.773842  60.540364   1.608477   1.663375
# 859         1.0892    MARCS  41.391990  60.440964   0.358247   0.381025
# 687         0.9895    MARCS  41.760699  60.667437   0.355979   0.334857
# 669         0.8392        A  41.971382  60.869417   0.208742   0.191189
# 673            NaN      NaN  41.851700  60.892318   0.215535   0.196625
# ..             ...      ...        ...        ...        ...        ...
# 465         0.4355    MARCS  41.991470  62.738418   0.643855   0.764214
# 452            NaN      NaN  41.114905  62.905420   0.294193   0.310339
# 83          0.5081  PHOENIX  40.787309  63.076058   1.053457   1.116594
# 540         0.6546        A  38.075178  62.268490   0.337357   0.360956
# 575         0.5765  PHOENIX  37.636518  62.354817   0.438373   0.475000
#
#      RADEcorJ2000  angDist
# 779       -0.1617      0.0
# 859       -0.1236      0.0
# 687       -0.1361      0.0
# 669       -0.1311      0.0
# 673       -0.0597      0.0
# ..            ...      ...
# 465       -0.1848      0.0
# 452       -0.1056      0.0
# 83        -0.3722      0.0
# 540       -0.0547      0.0
# 575       -0.0953      0.0
#
# [115 rows x 149 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(p1.RAJ2000, p1.DEJ2000, s=1, c='grey')
ax.scatter(dfvg.RAJ2000, dfvg.DEJ2000, s=1, c='b')
ax.scatter(p1.iloc[matched_idx_catalog1].RAJ2000, p1.iloc[matched_idx_catalog1].DEJ2000, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
# ax.set_ylim(-11.5,-14.2)
# ax.set_xlim(121.2,124.5)
# Out:
# Text(0, 0.5, 'DEC (deg)')

# %%
dfvg_t = len(dfvg)
p1_t = len(p1.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p1_c = p1_t /dfvg_t
p1_c*100
# Out:
# 19.262981574539364

# %% [markdown]
# Pureness

# %%
p1_p = p1_t/len(p1)
p1_p*100
# Out:
# 6.6320645905420985

# %% [markdown]
# ### Population 2

# %%
ra1 = p2.RAJ2000
dec1 = p2.DEJ2000

ra2 = dfvg.RAJ2000
dec2 = dfvg.DEJ2000

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p2
# Out:
#        RAJ2000    DEJ2000   pmRA   pmDE       Gmag     BP-RP     Plx  cluster
# 0    41.201648  59.656886 -2.224  3.729  16.880320  1.849627  1.0068        1
# 1    41.232358  59.705180 -3.707  3.279  19.948261  2.251060  1.0499        1
# 2    41.374028  59.780463 -0.820  3.253  16.351807  1.742498  1.0057        1
# 3    41.090346  59.764166 -1.709  1.128  19.790482  2.486855  0.9709        1
# 4    41.133014  59.766035 -3.188  2.751  17.974598  2.028555  0.9461        1
# ..         ...        ...    ...    ...        ...       ...     ...      ...
# 948  38.690398  63.302970 -1.676  2.734  20.683865  1.328360  0.9962        1
# 949  38.813226  63.350847 -1.381  1.840  20.730274  1.214121  1.0408        1
# 950  39.831522  63.498350 -2.642  2.533  19.477818  2.074942  1.0409        1
# 951  39.617222  63.511751 -3.310  2.758  19.599651  1.927876  0.9694        1
# 952  38.559067  63.342216 -0.797  0.830  20.814627  0.977436  1.0514        1
#
# [953 rows x 8 columns]

# %%
p2.iloc[matched_idx_catalog1]
# Out:
#        RAJ2000    DEJ2000   pmRA   pmDE       Gmag     BP-RP     Plx  cluster
# 269  38.665583  61.121015 -2.019  2.163  16.952963  1.708639  0.9549        1
# 345  40.422413  61.087284 -1.824  1.933  17.097599  1.682651  1.0374        1
# 363  40.607975  61.336185 -1.467  1.869  15.721642  1.443523  0.9886        1
# 383  40.166307  61.316390 -1.909  2.100  17.870052  1.944721  0.9878        1
# 401  40.589063  61.543107 -1.937  1.683  18.808035  2.175901  0.9863        1
# 412  40.039962  61.405432 -1.787  1.990  18.184263  1.992750  1.0378        1
# 417  39.904958  61.639553 -1.727  2.569  15.926031  1.415319  0.9649        1
# 425  40.453163  61.682358 -1.564  1.902  18.355396  2.034895  1.0154        1
# 427  40.295665  61.806122 -1.489  2.159  15.872344  1.288898  0.9963        1
# 454  41.139252  61.698372 -1.745  1.829  17.881641  1.789709  1.0672        1
# 483  41.785114  62.120273 -1.526  1.967  15.380888  1.347721  1.0281        1
# 487  40.814121  61.635384 -1.932  2.148  18.049477  1.850210  1.0441        1
# 488  40.856269  61.659073 -1.981  2.017  18.216188  1.869330  1.0239        1
# 493  40.873946  61.875409 -1.643  2.350  18.086191  1.864269  1.0158        1
# 495  41.389322  61.963846 -1.629  2.043  16.738688  1.492412  0.9640        1
# 501  41.029912  61.927261 -1.774  2.083  18.469168  2.248779  1.0370        1
# 505  40.647408  61.871765 -1.552  2.392  16.036766  1.468130  0.9833        1
# 508  40.765609  61.993786 -2.084  1.784  16.667645  1.483151  0.9854        1
# 513  40.833547  62.027899 -2.348  2.103  16.607548  1.547335  1.0130        1
# 531  41.527243  62.399219 -1.830  2.110  15.333253  1.278829  0.9978        1
# 552  39.477019  61.532111 -1.939  1.864  15.808213  1.345776  0.9874        1
# 553  39.446690  61.648633 -1.822  2.327  16.605627  1.501449  0.9906        1
# 575  40.080775  61.814781 -2.119  2.208  18.602232  2.077684  0.9937        1
# 605  38.950088  61.901575 -1.807  1.884  17.188015  1.636435  0.9577        1
# 639  40.352148  62.384449 -1.906  1.672  11.635002  0.625908  0.9600        1
# 658  40.799703  62.531996 -1.725  1.986  17.081020  1.657507  0.9817        1
# 666  40.418894  62.564516 -1.798  2.388  13.865103  0.935928  0.9564        1
# 787  42.672845  62.162149 -1.700  2.186  16.238014  1.464796  0.9654        1

# %%
dfvg.iloc[matched_idx_catalog2]
# Out:
#        Cluster             GaiaDR3    RA_ICRS    DE_ICRS     Plx   pmRA  \
# 851   NGC_1027  465462377723163776  38.665564  61.121025  0.9549 -2.019
# 1367  NGC_1027  465593494484211712  40.422396  61.087292  1.0374 -1.824
# 1097  NGC_1027  465621016635641856  40.607961  61.336193  0.9886 -1.467
# 982   NGC_1027  465646369819233152  40.166289  61.316399  0.9878 -1.909
# 990   NGC_1027  465676090993259904  40.589045  61.543114  0.9863 -1.937
# 359   NGC_1027  465682825501738752  40.039946  61.405440  1.0378 -1.787
# 275   NGC_1027  465689255077949184  39.904942  61.639565  0.9649 -1.727
# 16    NGC_1027  465693751899492736  40.453148  61.682366  1.0154 -1.564
# 28    NGC_1027  465698360408211584  40.295651  61.806132  0.9963 -1.489
# 757   NGC_1027  465726462371764608  41.139235  61.698380  1.0672 -1.745
# 681   NGC_1027  465767526560999040  41.785099  62.120282  1.0281 -1.526
# 648   NGC_1027  465771885945742336  40.814103  61.635393  1.0441 -1.932
# 649   NGC_1027  465771954665247104  40.856251  61.659082  1.0239 -1.981
# 504   NGC_1027  465778998409417344  40.873931  61.875420  1.0158 -1.643
# 516   NGC_1027  465782713566439936  41.389307  61.963855  0.9640 -1.629
# 523   NGC_1027  465784358528731008  41.029895  61.927270  1.0370 -1.774
# 608   NGC_1027  465789310636096000  40.647394  61.871775  0.9833 -1.552
# 623   NGC_1027  465792329988201344  40.765589  61.993794  0.9854 -2.084
# 579   NGC_1027  465797625692666112  40.833525  62.027908  1.0130 -2.348
# 390   NGC_1027  465821265193693184  41.527225  62.399228  0.9978 -1.830
# 1358  NGC_1027  465851776637578496  39.477001  61.532119  0.9874 -1.939
# 1321  NGC_1027  465856995016340736  39.446673  61.648643  0.9906 -1.822
# 1126  NGC_1027  465885620975594240  40.080755  61.814791  0.9937 -2.119
# 956   NGC_1027  465922660780883456  38.950071  61.901583  0.9577 -1.807
# 985   NGC_1027  465997118335548672  40.352130  62.384456  0.9600 -1.906
# 140   NGC_1027  466023644050466560  40.799686  62.532005  0.9817 -1.725
# 97    NGC_1027  466034982764139008  40.418877  62.564527  0.9564 -1.798
# 786   NGC_1027  467252240914244480  42.672829  62.162159  0.9654 -1.700
#
#        pmDE       Gmag      BPmag      RPmag  ...  E(BP-RP) b_E(BP-RP)_x  \
# 851   2.163  16.952963  17.767070  16.058432  ...    0.6107       0.5904
# 1367  1.933  17.097599  17.905810  16.223158  ...    0.5884       0.5729
# 1097  1.869  15.721642  16.366010  14.922488  ...    0.8980       0.8925
# 982   2.100  17.870052  18.870697  16.925976  ...    0.5783       0.5386
# 990   1.683  18.808035  19.929600  17.753698  ...    0.3553       0.3156
# 359   1.990  18.184263  19.211481  17.218730  ...    0.5804       0.5610
# 275   2.569  15.926031  16.564737  15.149418  ...    0.6031       0.5965
# 16    1.902  18.355396  19.390835  17.355940  ...    0.2308       0.2236
# 28    2.159  15.872344  16.438000  15.149102  ...    0.4950       0.4845
# 757   1.829  17.881641  18.762203  16.972494  ...    0.1769       0.1522
# 681   1.967  15.380888  15.976901  14.629180  ...    0.7878       0.7868
# 648   2.148  18.049477  18.976330  17.126120  ...    0.1322       0.1206
# 649   2.017  18.216188  19.136122  17.266792  ...    0.1820       0.1449
# 504   2.350  18.086191  19.022888  17.158619  ...    0.0866       0.0795
# 516   2.043  16.738688  17.411337  15.918925  ...    0.4717       0.4529
# 523   2.083  18.469168  19.664661  17.415882  ...    0.4815       0.4563
# 608   2.392  16.036766  16.704792  15.236662  ...    0.6297       0.6179
# 623   1.784  16.667645  17.347530  15.864380  ...    0.4736       0.4634
# 579   2.103  16.607548  17.331436  15.784102  ...    0.4861       0.4774
# 390   2.110  15.333253  15.886968  14.608139  ...    0.5664       0.5623
# 1358  1.864  15.808213  16.405394  15.059618  ...    0.5778       0.5633
# 1321  2.327  16.605627  17.290298  15.788850  ...    0.5203       0.5046
# 1126  2.208  18.602232  19.687593  17.609910  ...    0.5689       0.5473
# 956   1.884  17.188015  17.968311  16.331877  ...    0.5285       0.5070
# 985   1.672  11.635002  11.865830  11.239923  ...    0.7453       0.7433
# 140   1.986  17.081020  17.874979  16.217472  ...    0.5583       0.5422
# 97    2.388  13.865103  14.244426  13.308497  ...    0.7283       0.7138
# 786   2.186  16.238014  16.906803  15.442007  ...    0.5690       0.5599
#
#       B_E(BP-RP)_xa      Lib    RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  \
# 851          0.6388  PHOENIX  38.665583  61.121015   0.983082   1.052107
# 1367         0.6067  PHOENIX  40.422413  61.087284   1.107096   1.028673
# 1097         0.9041  PHOENIX  40.607975  61.336185   0.604599   0.684301
# 982          0.6168  PHOENIX  40.166307  61.316390   1.612400   1.622350
# 990          0.3961  PHOENIX  40.589063  61.543107   2.955155   2.931385
# 359          0.5982  PHOENIX  40.039962  61.405432   1.750966   2.055576
# 275          0.6127  PHOENIX  39.904958  61.639553   0.588095   0.586368
# 16           0.2388  PHOENIX  40.453163  61.682358   2.385173   2.302235
# 28           0.5077    MARCS  40.295665  61.806122   0.539888   0.682425
# 757          0.2133  PHOENIX  41.139252  61.698372   1.834638   1.642107
# 681          0.7926  PHOENIX  41.785114  62.120273   0.482333   0.504059
# 648          0.1428    MARCS  40.814121  61.635384   1.845365   1.717860
# 649          0.2107  PHOENIX  40.856269  61.659073   2.071610   1.863646
# 504          0.0940  PHOENIX  40.873946  61.875409   1.876911   1.904666
# 516          0.5064  PHOENIX  41.389322  61.963846   0.942736   0.926957
# 523          0.5221    MARCS  41.029912  61.927261   2.344793   2.342930
# 608          0.6512    MARCS  40.647408  61.871765   0.592412   0.614250
# 623          0.5054  PHOENIX  40.765609  61.993786   0.952419   0.935436
# 579          0.4953  PHOENIX  40.833547  62.027899   0.826844   0.812460
# 390          0.5704    MARCS  41.527243  62.399219   0.420842   0.509096
# 1358         0.5881    MARCS  39.477019  61.532111   0.509547   0.539707
# 1321         0.5432    MARCS  39.446690  61.648633   0.878256   0.956723
# 1126         0.5860  PHOENIX  40.080775  61.814781   2.667649   2.934599
# 956          0.5502  PHOENIX  38.950088  61.901575   1.107982   1.103261
# 985          0.7470        A  40.352148  62.384449   0.301676   0.335588
# 140          0.5725  PHOENIX  40.799703  62.531996   0.999452   1.078600
# 97           0.7313  PHOENIX  40.418894  62.564516   0.242437   0.240394
# 786          0.5761  PHOENIX  42.672845  62.162149   0.632334   0.661989
#
#       RADEcorJ2000  angDist
# 851        -0.0721      0.0
# 1367       -0.0489      0.0
# 1097       -0.0977      0.0
# 982        -0.0965      0.0
# 990        -0.0791      0.0
# 359         0.0071      0.0
# 275         0.0584      0.0
# 16         -0.0543      0.0
# 28         -0.1662      0.0
# 757        -0.0932      0.0
# 681        -0.0534      0.0
# 648        -0.0731      0.0
# 649        -0.1040      0.0
# 504        -0.1032      0.0
# 516        -0.1514      0.0
# 523        -0.1940      0.0
# 608        -0.0032      0.0
# 623        -0.1990      0.0
# 579        -0.1165      0.0
# 390        -0.0296      0.0
# 1358       -0.1025      0.0
# 1321        0.0112      0.0
# 1126       -0.2112      0.0
# 956        -0.0419      0.0
# 985        -0.0359      0.0
# 140        -0.0472      0.0
# 97         -0.1078      0.0
# 786        -0.0443      0.0
#
# [28 rows x 149 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(p2.RAJ2000, p2.DEJ2000, s=1, c='grey')
ax.scatter(dfvg.RAJ2000, dfvg.DEJ2000, s=1, c='b')
ax.scatter(p2.iloc[matched_idx_catalog1].RAJ2000, p2.iloc[matched_idx_catalog1].DEJ2000, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
# ax.set_ylim(-11.5,-14.2)
# ax.set_xlim(121.2,124.5)
# Out:
# Text(0, 0.5, 'DEC (deg)')

# %%
dfvg_t = len(dfvg)
p2_t = len(p2.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p2_c = p2_t /dfvg_t
p2_c*100
# Out:
# 4.690117252931323

# %% [markdown]
# Pureness

# %%
p2_p = p2_t/len(p2)
p2_p*100
# Out:
# 2.9380902413431267

# %% [markdown]
# ### Population 3

# %%
ra1 = p3.RAJ2000
dec1 = p3.DEJ2000

ra2 = dfvg.RAJ2000
dec2 = dfvg.DEJ2000

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p3.iloc[matched_idx_catalog1]
# Out:
#        RAJ2000    DEJ2000   pmRA   pmDE       Gmag     BP-RP     Plx  cluster
# 0    41.570289  61.173400 -1.596  2.023  16.192581  1.385247  0.8300        2
# 1    41.654516  61.223737 -1.741  1.936  16.519371  1.419205  0.9554        2
# 2    42.138641  61.394100 -1.764  2.044  11.991033  0.586641  0.8718        2
# 3    40.922431  61.094230 -1.855  2.050  15.765883  1.316134  0.9349        2
# 5    41.048818  61.210887 -1.796  2.100  17.792515  1.911211  0.8934        2
# ..         ...        ...    ...    ...        ...       ...     ...      ...
# 395  39.829059  61.962048 -1.874  1.971  13.433594  0.769400  0.9195        2
# 396  39.903335  62.069134 -1.854  2.083  15.574017  1.404285  0.9084        2
# 397  39.648931  62.152393 -1.944  1.996  13.535378  0.820275  0.8991        2
# 398  40.356295  62.084891 -1.865  1.984  17.112860  1.566267  0.9350        2
# 399  40.219997  62.132754 -1.839  2.067  14.237828  1.013434  0.9225        2
#
# [380 rows x 8 columns]

# %%
dfvg.iloc[matched_idx_catalog2]
# Out:
#        Cluster             GaiaDR3    RA_ICRS    DE_ICRS     Plx   pmRA  \
# 385   NGC_1027  464949661706849280  41.570274  61.173409  0.8300 -1.596
# 383   NGC_1027  464950211462625792  41.654500  61.223746  0.9554 -1.741
# 472   NGC_1027  464956361855632896  42.138625  61.394109  0.8718 -1.764
# 1174  NGC_1027  465602702895244800  40.922414  61.094239  0.9349 -1.855
# 1152  NGC_1027  465609536182815360  41.048801  61.210897  0.8934 -1.796
# ...        ...                 ...        ...        ...     ...    ...
# 1289  NGC_1027  465891152898391936  39.829041  61.962056  0.9195 -1.874
# 1298  NGC_1027  465893592439768320  39.903317  62.069143  0.9084 -1.854
# 1237  NGC_1027  465909294840009728  39.648913  62.152402  0.8991 -1.944
# 944   NGC_1027  465984336508841088  40.356277  62.084900  0.9350 -1.865
# 976   NGC_1027  465986947848942208  40.219980  62.132763  0.9225 -1.839
#
#        pmDE       Gmag      BPmag      RPmag  ...  E(BP-RP) b_E(BP-RP)_x  \
# 385   2.023  16.192581  16.815716  15.430469  ...    0.4325       0.4067
# 383   1.936  16.519371  17.166830  15.747625  ...    0.4332       0.4085
# 472   2.044  11.991033  12.207760  11.621119  ...       NaN          NaN
# 1174  2.050  15.765883  16.284992  14.968859  ...    0.4585       0.4220
# 1152  2.100  17.792515  18.752975  16.841764  ...    0.8250       0.8117
# ...     ...        ...        ...        ...  ...       ...          ...
# 1289  1.971  13.433594  13.734810  12.965410  ...    0.7420       0.7374
# 1298  2.083  15.574017  16.203865  14.799580  ...    0.5968       0.5918
# 1237  1.996  13.535378  13.855075  13.034800  ...       NaN          NaN
# 944   1.984  17.112860  17.850330  16.284063  ...    0.4242       0.4092
# 976   2.067  14.237828  14.656072  13.642637  ...    0.5951       0.5918
#
#       B_E(BP-RP)_xa      Lib    RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  \
# 385          0.4524    MARCS  41.570289  61.173400   0.565584   0.578736
# 383          0.4866  PHOENIX  41.654516  61.223737   0.689309   0.694405
# 472             NaN      NaN  42.138641  61.394100   0.258982   0.275284
# 1174         0.5039    MARCS  40.922431  61.094230   0.526392   0.591266
# 1152         0.8534    MARCS  41.048818  61.210887   1.969922   1.771919
# ...             ...      ...        ...        ...        ...        ...
# 1289         0.7453        A  39.829059  61.962048   0.215102   0.215644
# 1298         0.6019    MARCS  39.903335  62.069134   0.530975   0.582379
# 1237            NaN      NaN  39.648931  62.152393   0.218453   0.226783
# 944          0.4358    MARCS  40.356295  62.084891   1.100971   1.150360
# 976          0.5985    MARCS  40.219997  62.132754   0.287340   0.299561
#
#       RADEcorJ2000  angDist
# 385        -0.0684      0.0
# 383         0.0169      0.0
# 472        -0.0149      0.0
# 1174       -0.0540      0.0
# 1152        0.0069      0.0
# ...            ...      ...
# 1289       -0.1077      0.0
# 1298       -0.2449      0.0
# 1237       -0.1457      0.0
# 944        -0.1749      0.0
# 976        -0.1973      0.0
#
# [380 rows x 149 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(p3.RAJ2000, p3.DEJ2000, s=1, c='grey')
ax.scatter(dfvg.RAJ2000, dfvg.DEJ2000, s=1, c='b')
ax.scatter(p3.iloc[matched_idx_catalog1].RAJ2000, p3.iloc[matched_idx_catalog1].DEJ2000, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
# ax.set_ylim(-11.5,-14.2)
# ax.set_xlim(121.2,124.5)
# Out:
# Text(0, 0.5, 'DEC (deg)')

# %%
dfvg_t = len(dfvg)
p3_t = len(p3.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p3_c = p3_t /dfvg_t
p3_c*100
# Out:
# 63.65159128978225

# %% [markdown]
# Pureness

# %%
p3_p = p3_t/len(p3)
p3_p*100
# Out:
# 95.0

# %% [markdown]
# ### Population 4

# %%
ra1 = p4.RAJ2000
dec1 = p4.DEJ2000

ra2 = dfvg.RAJ2000
dec2 = dfvg.DEJ2000

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p4.iloc[matched_idx_catalog1]
# Out:
# Empty DataFrame
# Columns: [RAJ2000, DEJ2000, pmRA, pmDE, Gmag, BP-RP, Plx, cluster]
# Index: []

# %%
dfvg.iloc[matched_idx_catalog2]
# Out:
# Empty DataFrame
# Columns: [Cluster, GaiaDR3, RA_ICRS, DE_ICRS, Plx, pmRA, pmDE, Gmag, BPmag, RPmag, Pmemb, DR3Name, RAdeg, DEdeg, errHalfMaj, errHalfMin, errPosAng, SolID, Source, RandomI, e_RAdeg, e_DEdeg, Plx_x, e_Plx, RPlx, PM, pmRA_x, e_pmRA, pmDE_x, e_pmDE, RADEcor, RAPlxcor, RApmRAcor, RApmDEcor, DEPlxcor, DEpmRAcor, DEpmDEcor, PlxpmRAcor, PlxpmDEcor, pmRApmDEcor, NAL, NAC, NgAL, NbAL, gofAL, chi2AL, epsi, sepsi, Solved, APF, nueff, pscol, e_pscol, RApscolCorr, DEpscolCorr, PlxpscolCorr, pmRApscolCorr, pmDEpscolCorr, MatchObsA, Nper, amax, MatchObs, IPDgofha, IPDgofhp, IPDfmp, IPDfow, RUWE, Dup, o_Gmag, FG, e_FG, RFG, Gmag_x, e_Gmag, o_BPmag, FBP, e_FBP, RFBP, BPmag_x, e_BPmag, o_RPmag, FRP, e_FRP, RFRP, RPmag_x, e_RPmag, E(BP/RP), NBPcont, NBPblend, NRPcont, NRPblend, Mode, BP-RP, BP-G, G-RP, RV, e_RV, n_RV, o_RV, o_RVd, ...]
# Index: []
#
# [0 rows x 149 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(p4.RAJ2000, p4.DEJ2000, s=1, c='grey')
ax.scatter(dfvg.RA_ICRS, dfvg.DE_ICRS, s=1, c='b')
ax.scatter(p4.iloc[matched_idx_catalog1].RAJ2000, p4.iloc[matched_idx_catalog1].DEJ2000, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
# ax.set_ylim(-11.5,-14.2)
# ax.set_xlim(121.2,124.5)
# Out:
# Text(0, 0.5, 'DEC (deg)')

# %%
dfvg_t = len(dfvg)
p4_t = len(p4.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p4_c = p4_t /dfvg_t
p4_c*100
# Out:
# 0.0

# %% [markdown]
# Pureness

# %%
p4_p = p4_t/len(p4)
p4_p*100
# Out:
# 0.0

# %% [markdown]
# ### Population 5

# %%
ra1 = p5.RAJ2000
dec1 = p5.DEJ2000

ra2 = dfvg.RAJ2000
dec2 = dfvg.DEJ2000

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p5.iloc[matched_idx_catalog1]
# Out:
#        RAJ2000    DEJ2000   pmRA   pmDE       Gmag     BP-RP     Plx  cluster
# 39   38.918851  62.556110 -1.787  1.910  17.430868  1.722366  0.8259        4
# 84   39.226677  62.617298 -1.993  1.979  16.447214  1.525211  0.9070        4
# 143  39.696727  63.156079 -1.952  1.950  15.738831  1.278232  0.9259        4

# %%
dfvg.iloc[matched_idx_catalog2]
# Out:
#        Cluster             GaiaDR3    RA_ICRS    DE_ICRS     Plx   pmRA  \
# 1236  NGC_1027  465979934159829632  38.918833  62.556119  0.8259 -1.787
# 100   NGC_1027  466071434144149120  39.226658  62.617307  0.9070 -1.993
# 451   NGC_1027  466112807573205248  39.696708  63.156088  0.9259 -1.952
#
#        pmDE       Gmag      BPmag      RPmag  ...  E(BP-RP) b_E(BP-RP)_x  \
# 1236  1.910  17.430868  18.262980  16.540613  ...    0.5016       0.4827
# 100   1.979  16.447214  17.155657  15.630446  ...    0.6319       0.6197
# 451   1.950  15.738831  16.299076  15.020844  ...    0.4310       0.4143
#
#       B_E(BP-RP)_xa      Lib    RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  \
# 1236         0.5162  PHOENIX  38.918851  62.556110   1.275041   1.658349
# 100          0.6423    MARCS  39.226677  62.617298   0.761983   0.819195
# 451          0.4582    MARCS  39.696727  63.156079   0.277557   0.471373
#
#       RADEcorJ2000  angDist
# 1236       -0.2208      0.0
# 100        -0.2950      0.0
# 451        -0.5377      0.0
#
# [3 rows x 149 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(p5.RAJ2000, p5.DEJ2000, s=1, c='grey')
ax.scatter(dfvg.RAJ2000, dfvg.DEJ2000, s=1, c='b')
ax.scatter(p5.iloc[matched_idx_catalog1].RAJ2000, p5.iloc[matched_idx_catalog1].DEJ2000, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
# ax.set_ylim(-11.5,-14.2)
# ax.set_xlim(121.2,124.5)
# Out:
# Text(0, 0.5, 'DEC (deg)')

# %%
dfvg_t = len(dfvg)
p5_t = len(p5.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p5_c = p5_t /dfvg_t
p5_c*100
# Out:
# 0.5025125628140703

# %% [markdown]
# Pureness

# %%
p5_p = p5_t/len(p5)
p5_p*100
# Out:
# 0.539568345323741

# %% [markdown]
# ## Analyzing

# %%
import seaborn as sns

# Dados simulados: completude e pureza por cluster
clusters = [1, 2, 3, 4, 5]
completeness = [p1_c, p2_c, p3_c, p4_c, p5_c]  # Exemplo de completude
purity = [p1_p, p2_p, p3_p, p4_p, p5_p]  # Exemplo de pureza

# Bar plot
x = range(len(clusters))
plt.bar(x, completeness, width=0.4, label="Completeness", alpha=0.8, align='center')
plt.bar(x, purity, width=0.4, label="Purity", alpha=0.8, align='edge')

plt.xticks(x, [f"Cluster {c}" for c in clusters])
plt.ylabel("Value")
plt.title("Completeness and Purity by Cluster")
plt.legend()
plt.show()

# %%
ra1 = p1_2p.RA_ICRS
dec1 = p1_2p.DE_ICRS

ra2 = dfvg.RA_ICRS
dec2 = dfvg.DE_ICRS

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p1_2p.iloc[matched_idx_catalog1]
# Out:
#          RA_ICRS    DE_ICRS               Source  e_RA_ICRS  e_DE_ICRS  \
# 729   123.007680 -13.927760  5724918868422661120     0.0225     0.0210
# 1197  122.876573 -13.863225  5725107915705369984     0.0249     0.0203
# 1218  122.516375 -13.965907  5725113481983114240     0.0463     0.0348
# 1240  122.556156 -13.847291  5725116849237274752     0.0244     0.0198
# 1270  122.623225 -13.760115  5725126401244507904     0.0488     0.0377
# ...          ...        ...                  ...        ...        ...
# 6424  121.986992 -12.075530  5727777839175515520     0.0126     0.0085
# 6430  122.125904 -12.096970  5727779797680542464     0.0141     0.0096
# 6507  122.084503 -11.893047  5727798523739919360     0.0471     0.0336
# 6815  122.369838 -11.763095  5727883426649794560     0.0098     0.0077
# 6912  122.769462 -11.629920  5727912494988318336     0.0247     0.0231
#
#          Plx   e_Plx     PM   pmRA  e_pmRA  ...       Gmag      BPmag  \
# 729   0.8103  0.0328  2.498 -2.426   0.033  ...  15.580099  15.963792
# 1197  0.8040  0.0383  2.409 -2.290   0.041  ...  15.763227  16.162367
# 1218  0.7145  0.0745  2.281 -2.239   0.069  ...  17.050293  17.589607
# 1240  0.7071  0.0384  2.272 -2.152   0.035  ...  15.925107  16.289055
# 1270  0.7557  0.0697  2.415 -2.357   0.069  ...  17.152250  17.761162
# ...      ...     ...    ...    ...     ...  ...        ...        ...
# 6424  0.7857  0.0186  2.512 -2.378   0.019  ...  14.231053  14.491918
# 6430  0.7248  0.0215  2.197 -2.163   0.022  ...  14.497416  14.759340
# 6507  0.7568  0.0697  2.383 -2.357   0.069  ...  17.198061  17.843935
# 6815  0.7174  0.0149  2.419 -2.345   0.015  ...  13.256223  13.424639
# 6912  0.7955  0.0327  2.153 -2.062   0.034  ...  15.634084  16.025911
#
#           RPmag     BP-RP     RV       ELAT     RAJ2000    DEJ2000  Plx_corr  \
# 729   15.036696  0.927096    NaN -32.997611  123.007691 -13.927758  0.852579
# 1197  15.196784  0.965583    NaN -32.968078  122.876584 -13.863222  0.846286
# 1218  16.384487  1.205120    NaN -33.156968  122.516385 -13.965905  0.744836
# 1240  15.386557  0.902498    NaN -33.032424  122.556166 -13.847287  0.748479
# 1270  16.422697  1.338465    NaN -32.931504  122.623236 -13.760112  0.785536
# ...         ...       ...    ...        ...         ...        ...       ...
# 6424  13.813985  0.677933  32.14 -31.456736  121.987003 -12.075527  0.828046
# 6430  14.081089  0.678251  34.35 -31.443894  122.125913 -12.096969  0.767314
# 6507  16.455805  1.388130    NaN -31.256342  122.084513 -11.893045  0.785921
# 6815  12.966224  0.458415    NaN -31.061217  122.369849 -11.763092  0.759958
# 6912  15.070681  0.955231    NaN -30.834555  122.769471 -11.629917  0.838047
#
#       cluster
# 729         0
# 1197        0
# 1218        0
# 1240        0
# 1270        0
# ...       ...
# 6424        0
# 6430        0
# 6507        0
# 6815        0
# 6912        0
#
# [596 rows x 26 columns]

# %%
dfvg.iloc[matched_idx_catalog2]
# Out:
#                   GaiaDR3     RA_ICRS    DE_ICRS     Plx   pmRA   pmDE  \
# 1029  5724918868422661120  123.007680 -13.927760  0.8103 -2.426 -0.595
# 1022  5725107915705369984  122.876573 -13.863225  0.8040 -2.290 -0.747
# 971   5725113481983114240  122.516375 -13.965907  0.7145 -2.239 -0.433
# 967   5725116849237274752  122.556156 -13.847291  0.7071 -2.152 -0.728
# 961   5725126401244507904  122.623225 -13.760115  0.7557 -2.357 -0.526
# ...                   ...         ...        ...     ...    ...    ...
# 264   5727777839175515520  121.986992 -12.075530  0.7857 -2.378 -0.808
# 290   5727779797680542464  122.125904 -12.096970  0.7248 -2.163 -0.385
# 704   5727798523739919360  122.084503 -11.893047  0.7568 -2.357 -0.348
# 399   5727883426649794560  122.369838 -11.763095  0.7174 -2.345 -0.596
# 380   5727912494988318336  122.769462 -11.629920  0.7955 -2.062 -0.620
#
#            Gmag      BPmag      RPmag   Cluster  Pmemb
# 1029  15.580099  15.963792  15.036696  NGC_2539   1.00
# 1022  15.763227  16.162367  15.196784  NGC_2539   0.98
# 971   17.050293  17.589607  16.384487  NGC_2539   0.74
# 967   15.925107  16.289055  15.386557  NGC_2539   0.83
# 961   17.152250  17.761162  16.422697  NGC_2539   0.96
# ...         ...        ...        ...       ...    ...
# 264   14.231053  14.491918  13.813985  NGC_2539   1.00
# 290   14.497416  14.759340  14.081089  NGC_2539   1.00
# 704   17.198061  17.843935  16.455805  NGC_2539   0.87
# 399   13.256223  13.424639  12.966224  NGC_2539   1.00
# 380   15.634084  16.025911  15.070681  NGC_2539   0.80
#
# [596 rows x 11 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(p1_2p.RA_ICRS, p1_2p.DE_ICRS, s=1, c='grey')
ax.scatter(dfvg.RA_ICRS, dfvg.DE_ICRS, s=1, c='b')
ax.scatter(p1_2p.iloc[matched_idx_catalog1].RA_ICRS, p1_2p.iloc[matched_idx_catalog1].DE_ICRS, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
ax.set_ylim(-11.5,-14.2)
ax.set_xlim(121.2,124.5)
# Out:
# (121.2, 124.5)

# %%
dfvg_t = len(dfvg)
p1_2p_t = len(p1_2p.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p1_2p_c = p1_2p_t /dfvg_t
p1_2p_c*100
# Out:
# 90.99236641221374

# %% [markdown]
# Pureness

# %%
p1_2p_p = p1_2p_t/len(p1_2p)
p1_2p_p*100
# Out:
# 7.763449264035431

# %%
ra1 = p2_2p.RA_ICRS
dec1 = p2_2p.DE_ICRS

ra2 = dfvg.RA_ICRS
dec2 = dfvg.DE_ICRS

# %%
#Catalogue from my work with GMM
catalog1 = SkyCoord(ra=ra1, dec=dec1, unit='degree')
#Catalogue from vG+2023
catalog2 = SkyCoord(ra=ra2, dec=dec2, unit='degree')

# %%
idx, d2d, d3d = catalog1.match_to_catalog_sky(catalog2)

# %%
max_sep = 1.0 * u.arcsec  # Exemplo de separacao limite de 1 segundo de arco
matches = d2d < max_sep

# Selecionar apenas correspondências válidas
matched_idx = idx[matches]
matched_d2d = d2d[matches]

# %%
matched_idx_catalog1 = np.where(matches)[0]
matched_idx_catalog2 = idx[matches]

# %%
p2_2p.iloc[matched_idx_catalog1]
# Out:
#          RA_ICRS    DE_ICRS               Source  e_RA_ICRS  e_DE_ICRS  \
# 2574  122.921398 -13.185993  5726694747202461312     0.0559     0.0568
# 2589  122.425772 -13.241586  5726702409422712192     0.0697     0.0536
# 2608  122.595976 -13.031000  5726711690850248704     0.0512     0.0407
# 3142  122.547817 -12.972002  5727463511987435904     0.0968     0.0712
# 3145  122.621274 -12.911557  5727465612232588928     0.0736     0.0637
# 3152  122.557252 -12.840559  5727469254364865024     0.0329     0.0251
# 3154  122.493979 -12.845428  5727469765460098560     0.1364     0.1081
# 3205  122.690985 -12.804562  5727490145085719936     0.0655     0.0594
# 3209  122.719631 -12.805480  5727491588194718336     0.0588     0.0519
# 3213  122.624003 -12.807470  5727492859505082624     0.0467     0.0391
#
#          Plx   e_Plx     PM   pmRA  e_pmRA  ...       Gmag      BPmag  \
# 2574  0.6139  0.0780  2.329 -2.260   0.084  ...  17.271206  17.964739
# 2589  0.6523  0.1068  2.509 -2.426   0.105  ...  17.896448  18.671953
# 2608  0.6404  0.0811  2.347 -2.301   0.074  ...  17.062359  17.641851
# 3142  0.6307  0.1485  2.331 -2.296   0.147  ...  18.121515  18.958378
# 3145  0.6394  0.1189  2.387 -2.359   0.114  ...  17.720638  18.434364
# 3152  0.6488  0.0458  2.485 -2.475   0.047  ...  16.412067  16.879095
# 3154  0.6333  0.2040  2.351 -2.272   0.194  ...  18.827095  19.748213
# 3205  0.6499  0.0940  2.421 -2.346   0.095  ...  17.579407  18.285118
# 3209  0.6471  0.0780  2.373 -2.327   0.083  ...  17.026710  17.570848
# 3213  0.6429  0.0652  2.367 -2.307   0.069  ...  17.027517  17.609938
#
#           RPmag     BP-RP  RV       ELAT     RAJ2000    DEJ2000  Plx_corr  \
# 2574  16.480680  1.484058 NaN -32.302333  122.921408 -13.185990  0.643280
# 2589  17.053247  1.618706 NaN -32.478802  122.425783 -13.241584  0.679101
# 2608  16.351288  1.290564 NaN -32.233123  122.595987 -13.030998  0.670546
# 3142  17.246717  1.711660 NaN -32.187922  122.547828 -12.972000  0.656476
# 3145  16.915213  1.519152 NaN -32.111331  122.621285 -12.911555  0.667010
# 3152  15.787485  1.091610 NaN -32.058422  122.557264 -12.840558  0.681092
# 3154  17.843770  1.904444 NaN -32.078703  122.493990 -12.845425  0.655229
# 3205  16.796236  1.488882 NaN -31.990612  122.690996 -12.804559  0.678229
# 3209  16.323402  1.247446 NaN -31.984422  122.719641 -12.805478  0.677407
# 3213  16.332210  1.277727 NaN -32.009957  122.624013 -12.807467  0.673165
#
#       cluster
# 2574        1
# 2589        1
# 2608        1
# 3142        1
# 3145        1
# 3152        1
# 3154        1
# 3205        1
# 3209        1
# 3213        1
#
# [10 rows x 26 columns]

# %%
dfvg.iloc[matched_idx_catalog2]
# Out:
#                  GaiaDR3     RA_ICRS    DE_ICRS     Plx   pmRA   pmDE  \
# 321  5726694747202461312  122.921398 -13.185993  0.6139 -2.260 -0.563
# 307  5726702409422712192  122.425772 -13.241586  0.6523 -2.426 -0.640
# 297  5726711690850248704  122.595976 -13.031000  0.6404 -2.301 -0.463
# 481  5727463511987435904  122.547817 -12.972002  0.6307 -2.296 -0.400
# 574  5727465612232588928  122.621274 -12.911557  0.6394 -2.359 -0.363
# 557  5727469254364865024  122.557252 -12.840559  0.6488 -2.475 -0.222
# 863  5727469765460098560  122.493979 -12.845428  0.6333 -2.272 -0.604
# 714  5727490145085719936  122.690985 -12.804562  0.6499 -2.346 -0.597
# 812  5727491588194718336  122.719631 -12.805480  0.6471 -2.327 -0.465
# 790  5727492859505082624  122.624003 -12.807470  0.6429 -2.307 -0.527
#
#           Gmag      BPmag      RPmag   Cluster  Pmemb
# 321  17.271206  17.964739  16.480680  NGC_2539   0.78
# 307  17.896448  18.671953  17.053247  NGC_2539   0.73
# 297  17.062359  17.641851  16.351288  NGC_2539   0.90
# 481  18.121515  18.958378  17.246717  NGC_2539   0.71
# 574  17.720638  18.434364  16.915213  NGC_2539   0.72
# 557  16.412067  16.879095  15.787485  NGC_2539   0.91
# 863  18.827095  19.748213  17.843770  NGC_2539   0.70
# 714  17.579407  18.285118  16.796236  NGC_2539   0.96
# 812  17.026710  17.570848  16.323402  NGC_2539   0.96
# 790  17.027517  17.609938  16.332210  NGC_2539   0.96

# %%
fig, ax = plt.subplots()

ax.scatter(p2_2p.RA_ICRS, p2_2p.DE_ICRS, s=1, c='grey')
ax.scatter(dfvg.RA_ICRS, dfvg.DE_ICRS, s=1, c='b')
ax.scatter(p2_2p.iloc[matched_idx_catalog1].RA_ICRS, p2_2p.iloc[matched_idx_catalog1].DE_ICRS, s=4, c='r')
ax.set_xlabel('RA (deg)', fontsize=14)
ax.set_ylabel('DEC (deg)', fontsize=14)
ax.set_ylim(-11.5,-14.2)
ax.set_xlim(121.2,124.5)
# Out:
# (121.2, 124.5)

# %%
dfvg_t = len(dfvg)
p2_2p_t = len(p2_2p.iloc[matched_idx_catalog1])

# %% [markdown]
# Completeness

# %%
p2_2p_c = p2_2p_t /dfvg_t
p2_2p_c*100
# Out:
# 1.5267175572519083

# %% [markdown]
# Pureness

# %%
p2_2p_p = p2_2p_t/len(p2_2p)
p2_2p_p*100
# Out:
# 0.21853146853146854
